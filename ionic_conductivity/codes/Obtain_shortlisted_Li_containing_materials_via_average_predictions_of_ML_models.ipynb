# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Average_traditional_ML_model_predictions.csv')
df
# Out:
#       et_Average_prediction  catboost_Average_prediction  \
# 0                      0.05                         0.75
# 1                      0.31                         0.81
# 2                      1.00                         1.00
# 3                      0.52                         0.94
# 4                      0.88                         1.00
# ...                     ...                          ...
# 1068                   0.44                         0.94
# 1069                   0.04                         0.68
# 1070                   1.00                         1.00
# 1071                   0.83                         1.00
# 1072                   0.44                         0.94
#
#       RF_Average_prediction  LGBM_Average_prediction  ada_Average_prediction
# 0                      0.07                     0.07                    0.00
# 1                      0.15                     0.08                    0.02
# ...

# %%
df1 = pd.read_csv('Ionic_conductivity_validation_dataset.csv')
df1
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-1138  emmet_version='0.72.20' pymatgen_version='2023...       2
# 2        mp-1153  emmet_version='0.72.20' pymatgen_version='2023...       3
# 3        mp-1960  emmet_version='0.72.20' pymatgen_version='2023...       3
# 4        mp-2286  emmet_version='0.72.20' pymatgen_version='2023...       3
# ...          ...                                                ...     ...
# 1068  mp-1407206  emmet_version='0.72.20' pymatgen_version='2023...      12
# 1069  mp-1540429  emmet_version='0.72.20' pymatgen_version='2023...      16
# 1070  mp-2646995  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1071  mp-2647033  emmet_version='0.72.20' pymatgen_version='2023...      40
# 1072  mp-2659898  emmet_version='0.72.20' pymatgen_version='2023...      12
#
# ...

# %%
df3 = pd.concat([df1, df], axis = 1)
df3
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-1138  emmet_version='0.72.20' pymatgen_version='2023...       2
# 2        mp-1153  emmet_version='0.72.20' pymatgen_version='2023...       3
# 3        mp-1960  emmet_version='0.72.20' pymatgen_version='2023...       3
# 4        mp-2286  emmet_version='0.72.20' pymatgen_version='2023...       3
# ...          ...                                                ...     ...
# 1068  mp-1407206  emmet_version='0.72.20' pymatgen_version='2023...      12
# 1069  mp-1540429  emmet_version='0.72.20' pymatgen_version='2023...      16
# 1070  mp-2646995  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1071  mp-2647033  emmet_version='0.72.20' pymatgen_version='2023...      40
# 1072  mp-2659898  emmet_version='0.72.20' pymatgen_version='2023...      12
#
# ...

# %%
df4 = df3.copy()
df4
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-1138  emmet_version='0.72.20' pymatgen_version='2023...       2
# 2        mp-1153  emmet_version='0.72.20' pymatgen_version='2023...       3
# 3        mp-1960  emmet_version='0.72.20' pymatgen_version='2023...       3
# 4        mp-2286  emmet_version='0.72.20' pymatgen_version='2023...       3
# ...          ...                                                ...     ...
# 1068  mp-1407206  emmet_version='0.72.20' pymatgen_version='2023...      12
# 1069  mp-1540429  emmet_version='0.72.20' pymatgen_version='2023...      16
# 1070  mp-2646995  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1071  mp-2647033  emmet_version='0.72.20' pymatgen_version='2023...      40
# 1072  mp-2659898  emmet_version='0.72.20' pymatgen_version='2023...      12
#
# ...

# %%
for i in range(len(df.columns)):
    df4 = df4[df4[df.columns[i]] >= 0.5]

df4
# Out:
#      material_id                                       builder_meta  nsites  \
# 2        mp-1153  emmet_version='0.72.20' pymatgen_version='2023...       3
# 4        mp-2286  emmet_version='0.72.20' pymatgen_version='2023...       3
# 5        mp-2341  emmet_version='0.72.20' pymatgen_version='2023...       8
# 13       mp-3524  emmet_version='0.72.20' pymatgen_version='2023...       8
# 16       mp-3635  emmet_version='0.72.20' pymatgen_version='2023...      16
# ...          ...                                                ...     ...
# 1058  mp-1223097  emmet_version='0.72.20' pymatgen_version='2023...      32
# 1060  mp-1223173  emmet_version='0.72.20' pymatgen_version='2023...      40
# 1064  mp-1227900  emmet_version='0.72.20' pymatgen_version='2023...      20
# 1070  mp-2646995  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1071  mp-2647033  emmet_version='0.72.20' pymatgen_version='2023...      40
#
# ...

# %%
df5 = df4.copy()
df5
# Out:
#      material_id                                       builder_meta  nsites  \
# 2        mp-1153  emmet_version='0.72.20' pymatgen_version='2023...       3
# 4        mp-2286  emmet_version='0.72.20' pymatgen_version='2023...       3
# 5        mp-2341  emmet_version='0.72.20' pymatgen_version='2023...       8
# 13       mp-3524  emmet_version='0.72.20' pymatgen_version='2023...       8
# 16       mp-3635  emmet_version='0.72.20' pymatgen_version='2023...      16
# ...          ...                                                ...     ...
# 1058  mp-1223097  emmet_version='0.72.20' pymatgen_version='2023...      32
# 1060  mp-1223173  emmet_version='0.72.20' pymatgen_version='2023...      40
# 1064  mp-1227900  emmet_version='0.72.20' pymatgen_version='2023...      20
# 1070  mp-2646995  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1071  mp-2647033  emmet_version='0.72.20' pymatgen_version='2023...      40
#
# ...

# %%
df5.to_csv('Shortlisted_Li-containing_materials_via_average_predictions_of_traditional_ML_models.csv', index=False)
# !head Shortlisted_Li-containing_materials_via_average_predictions_of_traditional_ML_models.csv
# Out:
# material_id,builder_meta,nsites,elements,nelements,composition,composition_reduced,formula_pretty,formula_anonymous,chemsys,volume,density,density_atomic,symmetry,property_name,deprecated,deprecation_reasons,last_updated,origins,warnings,structure,task_ids,uncorrected_energy_per_atom,energy_per_atom,formation_energy_per_atom,energy_above_hull,is_stable,equilibrium_reaction_energy_per_atom,decomposes_to,xas,grain_boundaries,band_gap,cbm,vbm,efermi,is_gap_direct,is_metal,es_source_calc_id,bandstructure,dos,dos_energy_up,dos_energy_down,is_magnetic,ordering,total_magnetization,total_magnetization_normalized_vol,total_magnetization_normalized_formula_units,num_magnetic_sites,num_unique_magnetic_sites,types_of_magnetic_species,bulk_modulus,shear_modulus,universal_anisotropy,homogeneous_poisson,e_total,e_ionic,e_electronic,n,e_ij_max,weighted_surface_energy_EV_PER_ANG2,weighted_surface_energy,weighted_work_function,surface_anisotropy,shape_factor,has_reconstructed,possible_species,has_prop
# ...

# %%
df3.to_csv('Master_traditional_ML_models_average_predictions_of_ionic_conductivity.csv', index=False)
# !head Master_traditional_ML_models_average_predictions_of_ionic_conductivity.csv
# Out:
# material_id,builder_meta,nsites,elements,nelements,composition,composition_reduced,formula_pretty,formula_anonymous,chemsys,volume,density,density_atomic,symmetry,property_name,deprecated,deprecation_reasons,last_updated,origins,warnings,structure,task_ids,uncorrected_energy_per_atom,energy_per_atom,formation_energy_per_atom,energy_above_hull,is_stable,equilibrium_reaction_energy_per_atom,decomposes_to,xas,grain_boundaries,band_gap,cbm,vbm,efermi,is_gap_direct,is_metal,es_source_calc_id,bandstructure,dos,dos_energy_up,dos_energy_down,is_magnetic,ordering,total_magnetization,total_magnetization_normalized_vol,total_magnetization_normalized_formula_units,num_magnetic_sites,num_unique_magnetic_sites,types_of_magnetic_species,bulk_modulus,shear_modulus,universal_anisotropy,homogeneous_poisson,e_total,e_ionic,e_electronic,n,e_ij_max,weighted_surface_energy_EV_PER_ANG2,weighted_surface_energy,weighted_work_function,surface_anisotropy,shape_factor,has_reconstructed,possible_species,has_prop
# ...
