# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Master_traditional_ML_models_average_predictions_of_ionic_conductivity.csv')
df
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-1138  emmet_version='0.72.20' pymatgen_version='2023...       2
# 2        mp-1153  emmet_version='0.72.20' pymatgen_version='2023...       3
# 3        mp-1960  emmet_version='0.72.20' pymatgen_version='2023...       3
# 4        mp-2286  emmet_version='0.72.20' pymatgen_version='2023...       3
# ...          ...                                                ...     ...
# 1068  mp-1407206  emmet_version='0.72.20' pymatgen_version='2023...      12
# 1069  mp-1540429  emmet_version='0.72.20' pymatgen_version='2023...      16
# 1070  mp-2646995  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1071  mp-2647033  emmet_version='0.72.20' pymatgen_version='2023...      40
# 1072  mp-2659898  emmet_version='0.72.20' pymatgen_version='2023...      12
#
# ...

# %%
df1 = pd.read_csv('Shortlisted_Li-containing_materials_via_average_predictions_of_traditional_ML_models.csv')
df1
# Out:
#     material_id                                       builder_meta  nsites  \
# 0       mp-1153  emmet_version='0.72.20' pymatgen_version='2023...       3
# 1       mp-2286  emmet_version='0.72.20' pymatgen_version='2023...       3
# 2       mp-2341  emmet_version='0.72.20' pymatgen_version='2023...       8
# 3       mp-3524  emmet_version='0.72.20' pymatgen_version='2023...       8
# 4       mp-3635  emmet_version='0.72.20' pymatgen_version='2023...      16
# ..          ...                                                ...     ...
# 429  mp-1223097  emmet_version='0.72.20' pymatgen_version='2023...      32
# 430  mp-1223173  emmet_version='0.72.20' pymatgen_version='2023...      40
# 431  mp-1227900  emmet_version='0.72.20' pymatgen_version='2023...      20
# 432  mp-2646995  emmet_version='0.72.20' pymatgen_version='2023...       8
# 433  mp-2647033  emmet_version='0.72.20' pymatgen_version='2023...      40
#
#                                               elements  nelements  \
# ...

# %%
df4 = df1[df1['F'] != 0]
df4
# Out:
#     material_id                                       builder_meta  nsites  \
# 20      mp-6253  emmet_version='0.72.20' pymatgen_version='2023...      14
# 139   mp-560036  emmet_version='0.72.20' pymatgen_version='2023...     100
# 141   mp-560518  emmet_version='0.72.20' pymatgen_version='2023...      48
# 142   mp-560581  emmet_version='0.72.20' pymatgen_version='2023...      68
# 173   mp-690708  emmet_version='0.72.20' pymatgen_version='2023...      40
# 187   mp-720554  emmet_version='0.72.20' pymatgen_version='2023...      44
# 360  mp-1192391  emmet_version='0.72.20' pymatgen_version='2023...      26
# 367  mp-1195055  emmet_version='0.72.20' pymatgen_version='2023...      64
# 368  mp-1195057  emmet_version='0.72.20' pymatgen_version='2023...      78
# 376  mp-1196457  emmet_version='0.72.20' pymatgen_version='2023...      48
# 378  mp-1196828  emmet_version='0.72.20' pymatgen_version='2023...      36
# ...

# %%
df5 = df1[df1['Cl'] != 0]
df5
# Out:
#     material_id                                       builder_meta  nsites  \
# 57     mp-22905  emmet_version='0.72.20' pymatgen_version='2023...       2
# 58     mp-22961  emmet_version='0.72.20' pymatgen_version='2023...      14
# 59     mp-23122  emmet_version='0.72.20' pymatgen_version='2023...      51
# 61     mp-23416  emmet_version='0.72.20' pymatgen_version='2023...      28
# 63     mp-23648  emmet_version='0.72.20' pymatgen_version='2023...      46
# 93     mp-29149  emmet_version='0.72.20' pymatgen_version='2023...       6
# 94     mp-29151  emmet_version='0.72.20' pymatgen_version='2023...       8
# 95     mp-29344  emmet_version='0.72.20' pymatgen_version='2023...      40
# 105    mp-34038  emmet_version='0.72.20' pymatgen_version='2023...      10
# 108    mp-37498  emmet_version='0.72.20' pymatgen_version='2023...      16
# 111    mp-38008  emmet_version='0.72.20' pymatgen_version='2023...      14
# ...

# %%
df6 = df1[df1['Br'] != 0]
df6
# Out:
#     material_id                                       builder_meta  nsites  \
# 60     mp-23259  emmet_version='0.72.20' pymatgen_version='2023...       2
# 80     mp-28237  emmet_version='0.72.20' pymatgen_version='2023...       8
# 82     mp-28326  emmet_version='0.72.20' pymatgen_version='2023...      24
# 83     mp-28327  emmet_version='0.72.20' pymatgen_version='2023...      20
# 87     mp-28592  emmet_version='0.72.20' pymatgen_version='2023...      12
# 88     mp-28593  emmet_version='0.72.20' pymatgen_version='2023...       5
# 90     mp-28829  emmet_version='0.72.20' pymatgen_version='2023...      28
# 91     mp-28989  emmet_version='0.72.20' pymatgen_version='2023...      14
# 92     mp-29025  emmet_version='0.72.20' pymatgen_version='2023...       8
# 106    mp-34326  emmet_version='0.72.20' pymatgen_version='2023...      10
# 120   mp-554560  emmet_version='0.72.20' pymatgen_version='2023...      46
# ...

# %%
df7 = df1[df1['I'] != 0]
df7
# Out:
#     material_id                                       builder_meta  nsites  \
# 56     mp-22899  emmet_version='0.72.20' pymatgen_version='2023...       2
# 62     mp-23497  emmet_version='0.72.20' pymatgen_version='2023...      28
# 96     mp-29345  emmet_version='0.72.20' pymatgen_version='2023...      20
# 126   mp-557112  emmet_version='0.72.20' pymatgen_version='2023...      46
# 138   mp-559814  emmet_version='0.72.20' pymatgen_version='2023...      44
# 149   mp-568273  emmet_version='0.72.20' pymatgen_version='2023...       4
# 154   mp-570935  emmet_version='0.72.20' pymatgen_version='2023...       4
# 161   mp-643069  emmet_version='0.72.20' pymatgen_version='2023...      20
# 163   mp-643708  emmet_version='0.72.20' pymatgen_version='2023...      10
# 166   mp-675488  emmet_version='0.72.20' pymatgen_version='2023...      10
# 167   mp-675941  emmet_version='0.72.20' pymatgen_version='2023...      20
# ...

# %%
df8 = df1[df1['At'] != 0]
df8
# Out:
# Empty DataFrame
# ...

# %%
df9 = pd.concat([df4, df5, df6, df7, df8],
                  ignore_index = True)
df9
# Out:
#    material_id                                       builder_meta  nsites  \
# 0      mp-6253  emmet_version='0.72.20' pymatgen_version='2023...      14
# 1    mp-560036  emmet_version='0.72.20' pymatgen_version='2023...     100
# 2    mp-560518  emmet_version='0.72.20' pymatgen_version='2023...      48
# 3    mp-560581  emmet_version='0.72.20' pymatgen_version='2023...      68
# 4    mp-690708  emmet_version='0.72.20' pymatgen_version='2023...      40
# ..         ...                                                ...     ...
# 89  mp-1211168  emmet_version='0.72.20' pymatgen_version='2023...      46
# 90  mp-1211176  emmet_version='0.72.20' pymatgen_version='2023...      26
# 91  mp-1222482  emmet_version='0.72.20' pymatgen_version='2023...      13
# 92  mp-1222669  emmet_version='0.72.20' pymatgen_version='2023...       4
# 93  mp-1223173  emmet_version='0.72.20' pymatgen_version='2023...      40
#
#                                              elements  nelements  \
# ...

# %%
# Remove duplicates
duplicate = df9[df9.duplicated()]

print("Duplicate Rows :")
duplicate
# Out:
# Duplicate Rows :
#    material_id                                       builder_meta  nsites  \
# 92  mp-1222669  emmet_version='0.72.20' pymatgen_version='2023...       4
#
#                                elements  nelements composition  \
# 92  [Element Br, Element I, Element Li]          3  Li2 I1 Br1
#
#    composition_reduced formula_pretty formula_anonymous  chemsys  ...  \
# 92          Li2 I1 Br1         Li2IBr              ABC2  Br-I-Li  ...
#
#     crystal_system  crystal_system_int  is_centrosymmetric n_symmetry_ops  \
# 92        trigonal                   3               False             12
#
#    exists  et_Average_prediction  catboost_Average_prediction  \
# 92  False                    1.0                          1.0
#
#    RF_Average_prediction LGBM_Average_prediction ada_Average_prediction
# 92                   1.0                     1.0                    1.0
#
# [1 rows x 335 columns]

# %%
df9 = df9.drop_duplicates()
df9
# Out:
#    material_id                                       builder_meta  nsites  \
# 0      mp-6253  emmet_version='0.72.20' pymatgen_version='2023...      14
# 1    mp-560036  emmet_version='0.72.20' pymatgen_version='2023...     100
# 2    mp-560518  emmet_version='0.72.20' pymatgen_version='2023...      48
# 3    mp-560581  emmet_version='0.72.20' pymatgen_version='2023...      68
# 4    mp-690708  emmet_version='0.72.20' pymatgen_version='2023...      40
# ..         ...                                                ...     ...
# 88  mp-1180504  emmet_version='0.72.20' pymatgen_version='2023...      10
# 89  mp-1211168  emmet_version='0.72.20' pymatgen_version='2023...      46
# 90  mp-1211176  emmet_version='0.72.20' pymatgen_version='2023...      26
# 91  mp-1222482  emmet_version='0.72.20' pymatgen_version='2023...      13
# 93  mp-1223173  emmet_version='0.72.20' pymatgen_version='2023...      40
#
#                                              elements  nelements  \
# ...

# %%
df9.to_csv('Shortlisted_Li-halides_via_average_predictions_of_et_catboost_RF_ada_and_LGBM_only.csv', index=False)
# !head Shortlisted_Li-halides_via_average_predictions_of_et_catboost_RF_ada_and_LGBM_only.csv
# Out:
# material_id,builder_meta,nsites,elements,nelements,composition,composition_reduced,formula_pretty,formula_anonymous,chemsys,volume,density,density_atomic,symmetry,property_name,deprecated,deprecation_reasons,last_updated,origins,warnings,structure,task_ids,uncorrected_energy_per_atom,energy_per_atom,formation_energy_per_atom,energy_above_hull,is_stable,equilibrium_reaction_energy_per_atom,decomposes_to,xas,grain_boundaries,band_gap,cbm,vbm,efermi,is_gap_direct,is_metal,es_source_calc_id,bandstructure,dos,dos_energy_up,dos_energy_down,is_magnetic,ordering,total_magnetization,total_magnetization_normalized_vol,total_magnetization_normalized_formula_units,num_magnetic_sites,num_unique_magnetic_sites,types_of_magnetic_species,bulk_modulus,shear_modulus,universal_anisotropy,homogeneous_poisson,e_total,e_ionic,e_electronic,n,e_ij_max,weighted_surface_energy_EV_PER_ANG2,weighted_surface_energy,weighted_work_function,surface_anisotropy,shape_factor,has_reconstructed,possible_species,has_prop
# ...

# %%
df9['theoretical'].value_counts()
# Out:
# theoretical
# False    49
# True     44
# Name: count, dtype: int64

# %%
df10 = df9[df9['Cs'] == 0]
df10
# Out:
#    material_id                                       builder_meta  nsites  \
# 0      mp-6253  emmet_version='0.72.20' pymatgen_version='2023...      14
# 1    mp-560036  emmet_version='0.72.20' pymatgen_version='2023...     100
# 2    mp-560518  emmet_version='0.72.20' pymatgen_version='2023...      48
# 3    mp-560581  emmet_version='0.72.20' pymatgen_version='2023...      68
# 4    mp-690708  emmet_version='0.72.20' pymatgen_version='2023...      40
# ..         ...                                                ...     ...
# 88  mp-1180504  emmet_version='0.72.20' pymatgen_version='2023...      10
# 89  mp-1211168  emmet_version='0.72.20' pymatgen_version='2023...      46
# 90  mp-1211176  emmet_version='0.72.20' pymatgen_version='2023...      26
# 91  mp-1222482  emmet_version='0.72.20' pymatgen_version='2023...      13
# 93  mp-1223173  emmet_version='0.72.20' pymatgen_version='2023...      40
#
#                                              elements  nelements  \
# ...

# %%
df10.to_csv('Shortlisted_Li-halides_sans_Cs_via_average_predictions_of_et_catboost_RF_ada_and_LGBM_only.csv', index=False)
# !head Shortlisted_Li-halides_sans_Cs_via_average_predictions_of_et_catboost_RF_ada_and_LGBM_only.csv
# Out:
# material_id,builder_meta,nsites,elements,nelements,composition,composition_reduced,formula_pretty,formula_anonymous,chemsys,volume,density,density_atomic,symmetry,property_name,deprecated,deprecation_reasons,last_updated,origins,warnings,structure,task_ids,uncorrected_energy_per_atom,energy_per_atom,formation_energy_per_atom,energy_above_hull,is_stable,equilibrium_reaction_energy_per_atom,decomposes_to,xas,grain_boundaries,band_gap,cbm,vbm,efermi,is_gap_direct,is_metal,es_source_calc_id,bandstructure,dos,dos_energy_up,dos_energy_down,is_magnetic,ordering,total_magnetization,total_magnetization_normalized_vol,total_magnetization_normalized_formula_units,num_magnetic_sites,num_unique_magnetic_sites,types_of_magnetic_species,bulk_modulus,shear_modulus,universal_anisotropy,homogeneous_poisson,e_total,e_ionic,e_electronic,n,e_ij_max,weighted_surface_energy_EV_PER_ANG2,weighted_surface_energy,weighted_work_function,surface_anisotropy,shape_factor,has_reconstructed,possible_species,has_prop
# ...

# %%
df10['theoretical'].value_counts()
# Out:
# theoretical
# False    49
# True     44
# Name: count, dtype: int64
