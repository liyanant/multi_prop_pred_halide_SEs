# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pwd
# Out:
# /content

# %%
df1 = pd.read_csv('Shortlisted_Li-halides_sans_Cs_via_average_predictions_of_et_catboost_RF_ada_and_LGBM_only.csv').drop(['exists'], axis = 1)
df1
# Out:
#    material_id                                       builder_meta  nsites  \
# 0      mp-6253  emmet_version='0.72.20' pymatgen_version='2023...      14
# 1    mp-560036  emmet_version='0.72.20' pymatgen_version='2023...     100
# 2    mp-560518  emmet_version='0.72.20' pymatgen_version='2023...      48
# 3    mp-560581  emmet_version='0.72.20' pymatgen_version='2023...      68
# 4    mp-690708  emmet_version='0.72.20' pymatgen_version='2023...      40
# ..         ...                                                ...     ...
# 88  mp-1180504  emmet_version='0.72.20' pymatgen_version='2023...      10
# 89  mp-1211168  emmet_version='0.72.20' pymatgen_version='2023...      46
# 90  mp-1211176  emmet_version='0.72.20' pymatgen_version='2023...      26
# 91  mp-1222482  emmet_version='0.72.20' pymatgen_version='2023...      13
# 92  mp-1223173  emmet_version='0.72.20' pymatgen_version='2023...      40
#
#                                              elements  nelements  \
# ...

# %%
df1 = df1[df1['theoretical'] == True]
df1
# Out:
#    material_id                                       builder_meta  nsites  \
# 12  mp-1227900  emmet_version='0.72.20' pymatgen_version='2023...      20
# 21    mp-34038  emmet_version='0.72.20' pymatgen_version='2023...      10
# 22    mp-37498  emmet_version='0.72.20' pymatgen_version='2023...      16
# 23    mp-38008  emmet_version='0.72.20' pymatgen_version='2023...      14
# 24    mp-43030  emmet_version='0.72.20' pymatgen_version='2023...      46
# 25   mp-530738  emmet_version='0.72.20' pymatgen_version='2023...      82
# 30   mp-676109  emmet_version='0.72.20' pymatgen_version='2023...      60
# 32   mp-985585  emmet_version='0.72.20' pymatgen_version='2023...       5
# 33   mp-989512  emmet_version='0.72.20' pymatgen_version='2023...      10
# 34   mp-989579  emmet_version='0.72.20' pymatgen_version='2023...      10
# 35   mp-998230  emmet_version='0.72.20' pymatgen_version='2023...       5
# 36   mp-998591  emmet_version='0.72.20' pymatgen_version='2023...      10
# ...

# %%
len(df1)
# Out:
# 44

# %%
df2 = pd.read_csv('NEW_Shortlist_Li_halides_from_SCREENED_MPJ_18_July_2025.csv').drop(['exists'], axis = 1)
df2
# Out:
#    material_id                                       builder_meta  nsites  \
# 0      mp-6253  emmet_version='0.72.20' pymatgen_version='2023...      14
# 1      mp-6527  emmet_version='0.72.20' pymatgen_version='2023...      80
# 2      mp-6711  emmet_version='0.72.20' pymatgen_version='2023...      80
# 3     mp-15549  emmet_version='0.72.20' pymatgen_version='2023...      20
# 4    mp-555591  emmet_version='0.72.20' pymatgen_version='2023...      36
# 5    mp-556906  emmet_version='0.72.20' pymatgen_version='2023...      56
# 6    mp-556996  emmet_version='0.72.20' pymatgen_version='2023...      30
# 7    mp-560036  emmet_version='0.72.20' pymatgen_version='2023...     100
# 8    mp-703273  emmet_version='0.72.20' pymatgen_version='2023...      50
# 9    mp-989551  emmet_version='0.72.20' pymatgen_version='2023...      10
# 10   mp-989577  emmet_version='0.72.20' pymatgen_version='2023...      10
# 11  mp-1110656  emmet_version='0.72.20' pymatgen_version='2023...      10
# ...

# %%
df2 = df2[df2['theoretical'] == True]
df2
# Out:
#    material_id                                       builder_meta  nsites  \
# 8    mp-703273  emmet_version='0.72.20' pymatgen_version='2023...      50
# 9    mp-989551  emmet_version='0.72.20' pymatgen_version='2023...      10
# 10   mp-989577  emmet_version='0.72.20' pymatgen_version='2023...      10
# 11  mp-1110656  emmet_version='0.72.20' pymatgen_version='2023...      10
# 12  mp-1111671  emmet_version='0.72.20' pymatgen_version='2023...      10
# 13  mp-1113733  emmet_version='0.72.20' pymatgen_version='2023...      10
# 14  mp-1113747  emmet_version='0.72.20' pymatgen_version='2023...      10
# 15  mp-1180580  emmet_version='0.72.20' pymatgen_version='2023...       4
# 24  mp-1223441  emmet_version='0.72.20' pymatgen_version='2023...      10
# 26   mp-530738  emmet_version='0.72.20' pymatgen_version='2023...      82
# 28   mp-676109  emmet_version='0.72.20' pymatgen_version='2023...      60
# 29   mp-989583  emmet_version='0.72.20' pymatgen_version='2023...      10
# ...

# %%
df3 = pd.read_csv('NEW_Shortlist_Li_halides_4V_from_SCREENED_MPJ_18_July_2025.csv').drop(['exists'], axis = 1)
df3
# Out:
#    material_id                                       builder_meta  nsites  \
# 0      mp-6134  emmet_version='0.72.20' pymatgen_version='2023...      18
# 1      mp-6253  emmet_version='0.72.20' pymatgen_version='2023...      14
# 2      mp-6591  emmet_version='0.72.20' pymatgen_version='2023...      18
# 3      mp-9839  emmet_version='0.72.20' pymatgen_version='2023...      10
# 4     mp-10250  emmet_version='0.72.20' pymatgen_version='2023...       5
# 5     mp-15549  emmet_version='0.72.20' pymatgen_version='2023...      20
# 6     mp-24199  emmet_version='0.72.20' pymatgen_version='2023...       4
# 7    mp-555591  emmet_version='0.72.20' pymatgen_version='2023...      36
# 8    mp-556996  emmet_version='0.72.20' pymatgen_version='2023...      30
# 9    mp-989504  emmet_version='0.72.20' pymatgen_version='2023...      10
# 10  mp-1113747  emmet_version='0.72.20' pymatgen_version='2023...      10
# 11  mp-1114242  emmet_version='0.72.20' pymatgen_version='2023...      10
# ...

# %%
df3 = df3[df3['theoretical'] == True]
df3
# Out:
#    material_id                                       builder_meta  nsites  \
# 9    mp-989504  emmet_version='0.72.20' pymatgen_version='2023...      10
# 10  mp-1113747  emmet_version='0.72.20' pymatgen_version='2023...      10
# 11  mp-1114242  emmet_version='0.72.20' pymatgen_version='2023...      10
# 12  mp-1180580  emmet_version='0.72.20' pymatgen_version='2023...       4
# 16  mp-1209980  emmet_version='0.72.20' pymatgen_version='2023...      28
# 18  mp-1185319  emmet_version='0.72.20' pymatgen_version='2023...       4
#
#                                            elements  nelements  \
# 9    [Element F, Element Li, Element N, Element Na]          4
# 10  [Element Al, Element F, Element Li, Element Rb]          4
# 11  [Element F, Element Ga, Element Li, Element Na]          4
# 12               [Element F, Element H, Element Li]          3
# 16  [Element Be, Element F, Element Li, Element Na]          4
# 18                         [Element Cl, Element Li]          2
#
# ...

# %%
#merge two dataFrames and add indicator column
all_df1 = pd.merge(df1, df2, on=['material_id', 'formula_pretty', 'formation_energy_per_atom', 'energy_above_hull', 'band_gap', 'theoretical'], how='left', indicator='exists')


#add column to show if each row in first DataFrame exists in second
all_df1['exists'] = np.where(all_df1.exists == 'both', True, False)

#view updated DataFrame
all_df1
# Out:
#    material_id                                     builder_meta_x  nsites_x  \
# 0   mp-1227900  emmet_version='0.72.20' pymatgen_version='2023...        20
# 1     mp-34038  emmet_version='0.72.20' pymatgen_version='2023...        10
# 2     mp-37498  emmet_version='0.72.20' pymatgen_version='2023...        16
# 3     mp-38008  emmet_version='0.72.20' pymatgen_version='2023...        14
# 4     mp-43030  emmet_version='0.72.20' pymatgen_version='2023...        46
# 5    mp-530738  emmet_version='0.72.20' pymatgen_version='2023...        82
# 6    mp-676109  emmet_version='0.72.20' pymatgen_version='2023...        60
# 7    mp-985585  emmet_version='0.72.20' pymatgen_version='2023...         5
# 8    mp-989512  emmet_version='0.72.20' pymatgen_version='2023...        10
# 9    mp-989579  emmet_version='0.72.20' pymatgen_version='2023...        10
# 10   mp-998230  emmet_version='0.72.20' pymatgen_version='2023...         5
# ...

# %%
all_df1[all_df1['exists'] == True]
# Out:
#    material_id                                     builder_meta_x  nsites_x  \
# 5    mp-530738  emmet_version='0.72.20' pymatgen_version='2023...        82
# 6    mp-676109  emmet_version='0.72.20' pymatgen_version='2023...        60
# 16  mp-1110684  emmet_version='0.72.20' pymatgen_version='2023...        10
# 18  mp-1111660  emmet_version='0.72.20' pymatgen_version='2023...        10
# 41  mp-1211176  emmet_version='0.72.20' pymatgen_version='2023...        26
#
#                                           elements_x  nelements_x  \
# 5               [Element Cl, Element Li, Element Mg]            3
# 6               [Element Cl, Element In, Element Li]            3
# 16  [Element Bi, Element Cl, Element Li, Element Rb]            4
# 18   [Element Cl, Element K, Element Li, Element Tl]            4
# 41    [Element As, Element I, Element Li, Element S]            4
#
#       composition_x composition_reduced_x formula_pretty formula_anonymous_x  \
# ...

# %%
#merge two dataFrames and add indicator column
all_df2 = pd.merge(df2, df3, on=['material_id', 'formula_pretty', 'formation_energy_per_atom', 'energy_above_hull', 'band_gap', 'theoretical'], how='left', indicator='exists')


#add column to show if each row in first DataFrame exists in second
all_df2['exists'] = np.where(all_df2.exists == 'both', True, False)

#view updated DataFrame
all_df2
# Out:
#    material_id                                     builder_meta_x  nsites_x  \
# 0    mp-703273  emmet_version='0.72.20' pymatgen_version='2023...        50
# 1    mp-989551  emmet_version='0.72.20' pymatgen_version='2023...        10
# 2    mp-989577  emmet_version='0.72.20' pymatgen_version='2023...        10
# 3   mp-1110656  emmet_version='0.72.20' pymatgen_version='2023...        10
# 4   mp-1111671  emmet_version='0.72.20' pymatgen_version='2023...        10
# 5   mp-1113733  emmet_version='0.72.20' pymatgen_version='2023...        10
# 6   mp-1113747  emmet_version='0.72.20' pymatgen_version='2023...        10
# 7   mp-1180580  emmet_version='0.72.20' pymatgen_version='2023...         4
# 8   mp-1223441  emmet_version='0.72.20' pymatgen_version='2023...        10
# 9    mp-530738  emmet_version='0.72.20' pymatgen_version='2023...        82
# 10   mp-676109  emmet_version='0.72.20' pymatgen_version='2023...        60
# ...

# %%
all_df2[all_df2['exists'] == True]
# Out:
#   material_id                                     builder_meta_x  nsites_x  \
# 6  mp-1113747  emmet_version='0.72.20' pymatgen_version='2023...        10
# 7  mp-1180580  emmet_version='0.72.20' pymatgen_version='2023...         4
#
#                                         elements_x  nelements_x  \
# 6  [Element Al, Element F, Element Li, Element Rb]            4
# 7               [Element F, Element H, Element Li]            3
#
#   composition_reduced_x formula_pretty formula_anonymous_x   chemsys_x  \
# 6        Rb2 Li1 Al1 F6      Rb2LiAlF6              ABC2D6  Al-F-Li-Rb
# 7             Li1 H1 F2          LiHF2                ABC2      F-H-Li
#
#      volume_x  ...  catboost_RED_POT_Average_prediction  \
# 6  139.253079  ...                             0.499573
# 7   32.857139  ...                             1.271034
#
#    LGBM_RED_POT_Average_prediction xgboost_RED_POT_Average_prediction  \
# 6                         0.808286                           0.748506
# ...

# %%
#merge two dataFrames and add indicator column
all_df3 = pd.merge(df1, df3, on=['material_id', 'formula_pretty', 'formation_energy_per_atom', 'energy_above_hull', 'band_gap', 'theoretical'], how='left', indicator='exists')


#add column to show if each row in first DataFrame exists in second
all_df3['exists'] = np.where(all_df3.exists == 'both', True, False)

#view updated DataFrame
all_df3
# Out:
#    material_id                                     builder_meta_x  nsites_x  \
# 0   mp-1227900  emmet_version='0.72.20' pymatgen_version='2023...        20
# 1     mp-34038  emmet_version='0.72.20' pymatgen_version='2023...        10
# 2     mp-37498  emmet_version='0.72.20' pymatgen_version='2023...        16
# 3     mp-38008  emmet_version='0.72.20' pymatgen_version='2023...        14
# 4     mp-43030  emmet_version='0.72.20' pymatgen_version='2023...        46
# 5    mp-530738  emmet_version='0.72.20' pymatgen_version='2023...        82
# 6    mp-676109  emmet_version='0.72.20' pymatgen_version='2023...        60
# 7    mp-985585  emmet_version='0.72.20' pymatgen_version='2023...         5
# 8    mp-989512  emmet_version='0.72.20' pymatgen_version='2023...        10
# 9    mp-989579  emmet_version='0.72.20' pymatgen_version='2023...        10
# 10   mp-998230  emmet_version='0.72.20' pymatgen_version='2023...         5
# ...

# %%
all_df3[all_df3['exists'] == True]
# Out:
#    material_id                                     builder_meta_x  nsites_x  \
# 20  mp-1185319  emmet_version='0.72.20' pymatgen_version='2023...         4
#
#                   elements_x  nelements_x composition_x composition_reduced_x  \
# 20  [Element Cl, Element Li]            2       Li2 Cl2               Li1 Cl1
#
#    formula_pretty formula_anonymous_x chemsys_x  ...  \
# 20           LiCl                  AB     Cl-Li  ...
#
#     catboost_RED_POT_Average_prediction  LGBM_RED_POT_Average_prediction  \
# 20                             0.280778                         0.088034
#
#     xgboost_RED_POT_Average_prediction catboost_OXID_POT_Average_prediction  \
# 20                             0.22226                             4.286254
#
#    LGBM_OXID_POT_Average_prediction  xgboost_OXID_POT_Average_prediction  \
# 20                         4.265301                             4.475965
#
#     catboost_ESW  LGBM_ESW xgboost_ESW exists
# ...

# %%
df4 = all_df1[all_df1['exists'] == True]
df5 = all_df2[all_df2['exists'] == True]
df6 = all_df3[all_df3['exists'] == True]

# %%
df4
# Out:
#    material_id                                     builder_meta_x  nsites_x  \
# 5    mp-530738  emmet_version='0.72.20' pymatgen_version='2023...        82
# 6    mp-676109  emmet_version='0.72.20' pymatgen_version='2023...        60
# 16  mp-1110684  emmet_version='0.72.20' pymatgen_version='2023...        10
# 18  mp-1111660  emmet_version='0.72.20' pymatgen_version='2023...        10
# 41  mp-1211176  emmet_version='0.72.20' pymatgen_version='2023...        26
#
#                                           elements_x  nelements_x  \
# 5               [Element Cl, Element Li, Element Mg]            3
# 6               [Element Cl, Element In, Element Li]            3
# 16  [Element Bi, Element Cl, Element Li, Element Rb]            4
# 18   [Element Cl, Element K, Element Li, Element Tl]            4
# 41    [Element As, Element I, Element Li, Element S]            4
#
#       composition_x composition_reduced_x formula_pretty formula_anonymous_x  \
# ...

# %%
df5
# Out:
#   material_id                                     builder_meta_x  nsites_x  \
# 6  mp-1113747  emmet_version='0.72.20' pymatgen_version='2023...        10
# 7  mp-1180580  emmet_version='0.72.20' pymatgen_version='2023...         4
#
#                                         elements_x  nelements_x  \
# 6  [Element Al, Element F, Element Li, Element Rb]            4
# 7               [Element F, Element H, Element Li]            3
#
#   composition_reduced_x formula_pretty formula_anonymous_x   chemsys_x  \
# 6        Rb2 Li1 Al1 F6      Rb2LiAlF6              ABC2D6  Al-F-Li-Rb
# 7             Li1 H1 F2          LiHF2                ABC2      F-H-Li
#
#      volume_x  ...  catboost_RED_POT_Average_prediction  \
# 6  139.253079  ...                             0.499573
# 7   32.857139  ...                             1.271034
#
#    LGBM_RED_POT_Average_prediction xgboost_RED_POT_Average_prediction  \
# 6                         0.808286                           0.748506
# ...

# %%
df6
# Out:
#    material_id                                     builder_meta_x  nsites_x  \
# 20  mp-1185319  emmet_version='0.72.20' pymatgen_version='2023...         4
#
#                   elements_x  nelements_x composition_x composition_reduced_x  \
# 20  [Element Cl, Element Li]            2       Li2 Cl2               Li1 Cl1
#
#    formula_pretty formula_anonymous_x chemsys_x  ...  \
# 20           LiCl                  AB     Cl-Li  ...
#
#     catboost_RED_POT_Average_prediction  LGBM_RED_POT_Average_prediction  \
# 20                             0.280778                         0.088034
#
#     xgboost_RED_POT_Average_prediction catboost_OXID_POT_Average_prediction  \
# 20                             0.22226                             4.286254
#
#    LGBM_OXID_POT_Average_prediction  xgboost_OXID_POT_Average_prediction  \
# 20                         4.265301                             4.475965
#
#     catboost_ESW  LGBM_ESW xgboost_ESW exists
# ...

# %%
df4.columns[0:100]
# Out:
# Index(['material_id', 'builder_meta_x', 'nsites_x', 'elements_x',
#        'nelements_x', 'composition_x', 'composition_reduced_x',
#        'formula_pretty', 'formula_anonymous_x', 'chemsys_x', 'volume_x',
#        'density_x', 'density_atomic_x', 'symmetry_x', 'property_name_x',
#        'deprecated_x', 'deprecation_reasons_x', 'last_updated_x', 'origins_x',
#        'warnings_x', 'structure_x', 'task_ids_x',
#        'uncorrected_energy_per_atom_x', 'energy_per_atom_x',
#        'formation_energy_per_atom', 'energy_above_hull', 'is_stable_x',
#        'equilibrium_reaction_energy_per_atom_x', 'decomposes_to_x', 'xas_x',
#        'grain_boundaries_x', 'band_gap', 'cbm_x', 'vbm_x', 'efermi_x',
#        'is_gap_direct_x', 'is_metal_x', 'es_source_calc_id_x',
#        'bandstructure_x', 'dos_x', 'dos_energy_up_x', 'dos_energy_down_x',
#        'is_magnetic_x', 'ordering_x', 'total_magnetization_x',
#        'total_magnetization_normalized_vol_x',
# ...

# %%
df4.to_csv('Shortlist_theoretical_halides_with_good_ionic_conductivity_and_mech_prop_13_August_2025.csv', index = False)

# %%
df5.to_csv('Shortlist_theoretical_halides_with_good_mech_prop_and_ESW_13_August_2025.csv', index = False)

# %%
df6.to_csv('Shortlist_theoretical_halides_with_good_ESW_and_ionic_conductivity_13_August_2025.csv', index = False)
