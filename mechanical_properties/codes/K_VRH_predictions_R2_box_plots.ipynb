# %%
# !pwd
# Out:
# /Users/Anthony_1/Documents/PhD_stuff/Codes/Accelerated Discovery of Novel Garnet-Type Solid-State Electrolyte Candidates via Machine Learning/For_Practice/17_July_2025

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
K_VRH_trad_train_df = pd.read_csv('Trad_ML/K_VRH/K_VRH_TRAIN_R2.csv')
K_VRH_trad_train_df
# Out:
#     catboost      LGBM   xgboost
# 0   0.915810  0.912490  0.922645
# 1   0.914450  0.910685  0.921899
# 2   0.917030  0.916113  0.924176
# 3   0.915443  0.912011  0.921106
# 4   0.914429  0.910749  0.922100
# ..       ...       ...       ...
# 95  0.916844  0.913975  0.923832
# 96  0.915800  0.912885  0.921584
# 97  0.913740  0.909273  0.921206
# 98  0.917136  0.910953  0.922513
# 99  0.913935  0.910279  0.920526
#
# [100 rows x 3 columns]

# %%
K_VRH_trad_train_df.describe()
# Out:
#          catboost        LGBM     xgboost
# count  100.000000  100.000000  100.000000
# mean     0.916574    0.913906    0.924102
# std      0.001987    0.002866    0.002322
# min      0.912400    0.907788    0.919414
# 25%      0.915375    0.912053    0.922525
# 50%      0.916535    0.913621    0.923880
# 75%      0.917724    0.915717    0.925487
# max      0.923630    0.922769    0.930763

# %%
K_VRH_trad_train_df = K_VRH_trad_train_df[['catboost', 'LGBM', 'xgboost']]
K_VRH_trad_train_df
# Out:
#     catboost      LGBM   xgboost
# 0   0.915810  0.912490  0.922645
# 1   0.914450  0.910685  0.921899
# 2   0.917030  0.916113  0.924176
# 3   0.915443  0.912011  0.921106
# 4   0.914429  0.910749  0.922100
# ..       ...       ...       ...
# 95  0.916844  0.913975  0.923832
# 96  0.915800  0.912885  0.921584
# 97  0.913740  0.909273  0.921206
# 98  0.917136  0.910953  0.922513
# 99  0.913935  0.910279  0.920526
#
# [100 rows x 3 columns]

# %%
K_VRH_skorch_train_df = pd.read_csv('Skorch_NN/K_VRH/K_VRH_TRAIN_R2.csv')
K_VRH_skorch_train_df
# Out:
#     skorch_model_1  skorch_model_2  skorch_model_3
# 0         0.872215        0.871503        0.873117
# 1         0.873537        0.871755        0.874027
# 2         0.871469        0.874282        0.872221
# 3         0.871864        0.872361        0.872801
# 4         0.873317        0.871691        0.871763
# ..             ...             ...             ...
# 95        0.871230        0.871702        0.873153
# 96        0.872757        0.872740        0.870513
# 97        0.872766        0.872178        0.871409
# 98        0.873365        0.872433        0.871958
# 99        0.871124        0.872244        0.873684
#
# [100 rows x 3 columns]

# %%
K_VRH_skorch_train_df.describe()
# Out:
#        skorch_model_1  skorch_model_2  skorch_model_3
# count      100.000000      100.000000      100.000000
# mean         0.872390        0.872387        0.872478
# std          0.000920        0.000936        0.000895
# min          0.869510        0.870060        0.870513
# 25%          0.871861        0.871754        0.871820
# 50%          0.872347        0.872258        0.872510
# 75%          0.872955        0.872960        0.873124
# max          0.874891        0.874801        0.874724

# %%
K_VRH_skorch_train_df.columns = ['skorch_1', 'skorch_2', 'skorch_3']
K_VRH_skorch_train_df
# Out:
#     skorch_1  skorch_2  skorch_3
# 0   0.872215  0.871503  0.873117
# 1   0.873537  0.871755  0.874027
# 2   0.871469  0.874282  0.872221
# 3   0.871864  0.872361  0.872801
# 4   0.873317  0.871691  0.871763
# ..       ...       ...       ...
# 95  0.871230  0.871702  0.873153
# 96  0.872757  0.872740  0.870513
# 97  0.872766  0.872178  0.871409
# 98  0.873365  0.872433  0.871958
# 99  0.871124  0.872244  0.873684
#
# [100 rows x 3 columns]

# %%
K_VRH_train_df = pd.concat([K_VRH_trad_train_df, K_VRH_skorch_train_df], axis = 1)
K_VRH_train_df
# Out:
#     catboost      LGBM   xgboost  skorch_1  skorch_2  skorch_3
# 0   0.915810  0.912490  0.922645  0.872215  0.871503  0.873117
# 1   0.914450  0.910685  0.921899  0.873537  0.871755  0.874027
# 2   0.917030  0.916113  0.924176  0.871469  0.874282  0.872221
# 3   0.915443  0.912011  0.921106  0.871864  0.872361  0.872801
# 4   0.914429  0.910749  0.922100  0.873317  0.871691  0.871763
# ..       ...       ...       ...       ...       ...       ...
# 95  0.916844  0.913975  0.923832  0.871230  0.871702  0.873153
# 96  0.915800  0.912885  0.921584  0.872757  0.872740  0.870513
# 97  0.913740  0.909273  0.921206  0.872766  0.872178  0.871409
# 98  0.917136  0.910953  0.922513  0.873365  0.872433  0.871958
# 99  0.913935  0.910279  0.920526  0.871124  0.872244  0.873684
#
# [100 rows x 6 columns]

# %%
K_VRH_trad_test_df = pd.read_csv('Trad_ML/K_VRH/K_VRH_HOLDOUT_R2.csv')
K_VRH_trad_test_df
# Out:
#     catboost      LGBM   xgboost
# 0   0.852151  0.859823  0.856852
# 1   0.847938  0.858438  0.856390
# 2   0.829458  0.830682  0.833339
# 3   0.845355  0.851680  0.852441
# 4   0.858652  0.871214  0.866908
# ..       ...       ...       ...
# 95  0.833765  0.837856  0.839742
# 96  0.847346  0.853654  0.854768
# 97  0.857973  0.860681  0.860899
# 98  0.854053  0.867966  0.863669
# 99  0.854556  0.863919  0.865703
#
# [100 rows x 3 columns]

# %%
K_VRH_trad_test_df.describe()
# Out:
#          catboost        LGBM     xgboost
# count  100.000000  100.000000  100.000000
# mean     0.838062    0.845599    0.844356
# std      0.015272    0.015521    0.015471
# min      0.798346    0.810293    0.806391
# 25%      0.829362    0.837009    0.835843
# 50%      0.839969    0.845744    0.845655
# 75%      0.848145    0.856949    0.855343
# max      0.868159    0.873896    0.872958

# %%
K_VRH_trad_test_df = K_VRH_trad_test_df[['catboost', 'LGBM', 'xgboost']]
K_VRH_trad_test_df
# Out:
#     catboost      LGBM   xgboost
# 0   0.852151  0.859823  0.856852
# 1   0.847938  0.858438  0.856390
# 2   0.829458  0.830682  0.833339
# 3   0.845355  0.851680  0.852441
# 4   0.858652  0.871214  0.866908
# ..       ...       ...       ...
# 95  0.833765  0.837856  0.839742
# 96  0.847346  0.853654  0.854768
# 97  0.857973  0.860681  0.860899
# 98  0.854053  0.867966  0.863669
# 99  0.854556  0.863919  0.865703
#
# [100 rows x 3 columns]

# %%
K_VRH_skorch_test_df = pd.read_csv('Skorch_NN/K_VRH/K_VRH_HOLDOUT_R2.csv')
K_VRH_skorch_test_df
# Out:
#     skorch_model_1  skorch_model_2  skorch_model_3
# 0         0.831284        0.830861        0.832476
# 1         0.832246        0.832895        0.832575
# 2         0.831218        0.833800        0.831730
# 3         0.833803        0.832016        0.831619
# 4         0.833903        0.830876        0.834606
# ..             ...             ...             ...
# 95        0.832030        0.831526        0.833410
# 96        0.833730        0.833391        0.830406
# 97        0.831143        0.831542        0.829975
# 98        0.833288        0.832160        0.831301
# 99        0.832395        0.833794        0.831510
#
# [100 rows x 3 columns]

# %%
K_VRH_skorch_test_df.describe()
# Out:
#        skorch_model_1  skorch_model_2  skorch_model_3
# count      100.000000      100.000000      100.000000
# mean         0.832142        0.832167        0.832016
# std          0.001233        0.001223        0.001316
# min          0.829462        0.829677        0.828775
# 25%          0.831387        0.831330        0.831160
# 50%          0.832141        0.832122        0.832036
# 75%          0.832814        0.832788        0.832810
# max          0.836179        0.835304        0.835067

# %%
K_VRH_skorch_test_df.columns = ['skorch_1', 'skorch_2', 'skorch_3']
K_VRH_skorch_test_df
# Out:
#     skorch_1  skorch_2  skorch_3
# 0   0.831284  0.830861  0.832476
# 1   0.832246  0.832895  0.832575
# 2   0.831218  0.833800  0.831730
# 3   0.833803  0.832016  0.831619
# 4   0.833903  0.830876  0.834606
# ..       ...       ...       ...
# 95  0.832030  0.831526  0.833410
# 96  0.833730  0.833391  0.830406
# 97  0.831143  0.831542  0.829975
# 98  0.833288  0.832160  0.831301
# 99  0.832395  0.833794  0.831510
#
# [100 rows x 3 columns]

# %%
K_VRH_test_df = pd.concat([K_VRH_trad_test_df, K_VRH_skorch_test_df], axis = 1)
K_VRH_test_df
# Out:
#     catboost      LGBM   xgboost  skorch_1  skorch_2  skorch_3
# 0   0.852151  0.859823  0.856852  0.831284  0.830861  0.832476
# 1   0.847938  0.858438  0.856390  0.832246  0.832895  0.832575
# 2   0.829458  0.830682  0.833339  0.831218  0.833800  0.831730
# 3   0.845355  0.851680  0.852441  0.833803  0.832016  0.831619
# 4   0.858652  0.871214  0.866908  0.833903  0.830876  0.834606
# ..       ...       ...       ...       ...       ...       ...
# 95  0.833765  0.837856  0.839742  0.832030  0.831526  0.833410
# 96  0.847346  0.853654  0.854768  0.833730  0.833391  0.830406
# 97  0.857973  0.860681  0.860899  0.831143  0.831542  0.829975
# 98  0.854053  0.867966  0.863669  0.833288  0.832160  0.831301
# 99  0.854556  0.863919  0.865703  0.832395  0.833794  0.831510
#
# [100 rows x 6 columns]

# %%
labels = K_VRH_test_df.columns

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(30, 10))

plt.rcParams.update({'font.size': 22, 'font.weight':'bold'})
bplot1 = ax1.boxplot(K_VRH_train_df,
                     vert=True,
                     patch_artist=True,
                     labels=labels)
ax1.set_title('Training Rectangular box plot', fontsize = 24, fontweight='bold')


bplot2 = ax2.boxplot(K_VRH_test_df,
                     vert=True,
                     patch_artist=True,
                     labels=labels)
ax2.set_title('Holdout Rectangular box plot', fontsize = 24, fontweight='bold')

colors = ['red', 'blue', 'orange', 'violet', 'yellow', 'green', 'pink', 'brown', 'lightblue', 'magenta', 'lightgreen', 'cyan', 'beige']
for bplot in (bplot1, bplot2):
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)

for ax in [ax1, ax2]:
    ax.yaxis.grid(False)
    ax.xaxis.grid(False)
    ax.set_ylabel('$\mathregular{R^2}$', fontsize = 24, fontweight='bold')

plt.show()
