# %% [markdown]
# # Reduction potential Skorch_NN optimised hyperparameters

# %%
torch.manual_seed(0)

# %%
from torch import nn
import torch.nn.functional as F

class Regressor(nn.Module):
    def __init__(self, num_inputs=len(X.columns), num_units_d1=100, num_units_d2=100, dropout = 0.2):
        super(Regressor, self).__init__()

        self.first_layer = nn.Linear(num_inputs, num_units_d1)
        self.dropout = nn.Dropout(dropout)
        self.second_layer = nn.Linear(num_units_d1,num_units_d2)
        self.final_layer = nn.Linear(num_units_d2,1)

    def forward(self, x_batch):
        X = self.first_layer(x_batch)
        X = F.relu(X)
        X= self.dropout(X)
        X = self.second_layer(X)
        X = F.relu(X)

        return self.final_layer(X)

# %%
from skorch import NeuralNetRegressor
from torch import optim

skorch_regressor = NeuralNetRegressor(module=Regressor, optimizer=optim.Adam, max_epochs=200, verbose=0, lr = 0.0001, batch_size = 32)

skorch_regressor
# Out:
# <class 'skorch.regressor.NeuralNetRegressor'>[uninitialized](
#   module=<class '__main__.Regressor'>,
# )

# %%
skorch_regressor.initialize().load_params(
                              f_params="Reduction_potential/Skorch_NN/params.pkl",
                              f_optimizer="Reduction_potential/Skorch_NN/opt.pkl",
                              f_criterion="Reduction_potential/Skorch_NN/criterion.pkl",
                              f_history="Reduction_potential/Skorch_NN/hist.json"
                            )

# %% [markdown]
# # Oxidation potential Skorch_NN optimised hyperparameters

# %%
torch.manual_seed(0)

# %%
from torch import nn
import torch.nn.functional as F

class Regressor(nn.Module):
    def __init__(self, num_inputs=len(X.columns), num_units_d1=300, num_units_d2=100, dropout = 0.5):
        super(Regressor, self).__init__()

        self.first_layer = nn.Linear(num_inputs, num_units_d1)
        self.dropout = nn.Dropout(dropout)
        self.second_layer = nn.Linear(num_units_d1,num_units_d2)
        self.final_layer = nn.Linear(num_units_d2,1)

    def forward(self, x_batch):
        X = self.first_layer(x_batch)
        X = F.relu(X)
        X= self.dropout(X)
        X = self.second_layer(X)
        X = F.relu(X)

        return self.final_layer(X)

# %%
from skorch import NeuralNetRegressor
from torch import optim

skorch_regressor = NeuralNetRegressor(module=Regressor, optimizer=optim.Adam, max_epochs=200, verbose=0, lr = 0.0005, train_split=None, batch_size = 64)

skorch_regressor
# Out:
# <class 'skorch.regressor.NeuralNetRegressor'>[uninitialized](
#   module=<class '__main__.Regressor'>,
# )

# %%
skorch_regressor.initialize().load_params(
                              f_params="Oxidation_potential/Skorch_NN/params.pkl",
                              f_optimizer="Oxidation_potential/Skorch_NN/opt.pkl",
                              f_criterion="Oxidation_potential/Skorch_NN/criterion.pkl",
                              f_history="Oxidation_potential/Skorch_NN/hist.json"
                            )
