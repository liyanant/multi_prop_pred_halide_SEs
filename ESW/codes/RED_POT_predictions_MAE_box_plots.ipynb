# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
RED_POT_trad_train_df = pd.read_csv('Trad_ML/Reduction_potential/RED_POT_TRAIN_MAE.csv')
RED_POT_trad_train_df
# Out:
#     catboost      LGBM   xgboost
# 0   0.097439  0.097672  0.115362
# 1   0.095706  0.095866  0.115569
# 2   0.096531  0.097423  0.117304
# 3   0.094663  0.096009  0.122557
# 4   0.102819  0.096146  0.118688
# ..       ...       ...       ...
# 95  0.098747  0.100733  0.124680
# 96  0.102322  0.096265  0.122826
# 97  0.097428  0.096219  0.120741
# 98  0.093988  0.092564  0.117486
# 99  0.094802  0.096219  0.120614
#
# [100 rows x 3 columns]

# %%
RED_POT_trad_train_df.describe()
# Out:
#          catboost        LGBM     xgboost
# count  100.000000  100.000000  100.000000
# mean     0.096778    0.096511    0.119319
# std      0.002916    0.002528    0.003388
# min      0.087377    0.089363    0.110860
# 25%      0.094794    0.095168    0.116823
# 50%      0.097145    0.096377    0.119157
# 75%      0.098601    0.098291    0.121924
# max      0.103290    0.101656    0.126640

# %%
RED_POT_trad_train_df = RED_POT_trad_train_df[['catboost', 'LGBM', 'xgboost']]
RED_POT_trad_train_df
# Out:
#     catboost      LGBM   xgboost
# 0   0.097439  0.097672  0.115362
# 1   0.095706  0.095866  0.115569
# 2   0.096531  0.097423  0.117304
# 3   0.094663  0.096009  0.122557
# 4   0.102819  0.096146  0.118688
# ..       ...       ...       ...
# 95  0.098747  0.100733  0.124680
# 96  0.102322  0.096265  0.122826
# 97  0.097428  0.096219  0.120741
# 98  0.093988  0.092564  0.117486
# 99  0.094802  0.096219  0.120614
#
# [100 rows x 3 columns]

# %%
RED_POT_skorch_train_df = pd.read_csv('Skorch_NN/Reduction_potential/RED_POT_TRAIN_MAE.csv')
RED_POT_skorch_train_df
# Out:
#     skorch_model_1  skorch_model_2  skorch_model_3
# 0         0.187553        0.185731        0.185748
# 1         0.185183        0.188696        0.184692
# 2         0.187439        0.190559        0.181684
# 3         0.186022        0.192209        0.185410
# 4         0.189756        0.193418        0.186575
# ..             ...             ...             ...
# 95        0.188806        0.193116        0.191533
# 96        0.199352        0.196767        0.188936
# 97        0.189797        0.190970        0.188888
# 98        0.189628        0.188354        0.189799
# 99        0.186179        0.187812        0.187121
#
# [100 rows x 3 columns]

# %%
RED_POT_skorch_train_df.describe()
# Out:
#        skorch_model_1  skorch_model_2  skorch_model_3
# count      100.000000      100.000000      100.000000
# mean         0.188732        0.188659        0.188585
# std          0.004174        0.004260        0.004191
# min          0.180643        0.176864        0.178580
# 25%          0.185514        0.185417        0.186036
# 50%          0.188783        0.188940        0.188435
# 75%          0.191267        0.191972        0.191200
# max          0.199352        0.197326        0.200048

# %%
RED_POT_skorch_train_df.columns = ['skorch_1', 'skorch_2', 'skorch_3']
RED_POT_skorch_train_df
# Out:
#     skorch_1  skorch_2  skorch_3
# 0   0.187553  0.185731  0.185748
# 1   0.185183  0.188696  0.184692
# 2   0.187439  0.190559  0.181684
# 3   0.186022  0.192209  0.185410
# 4   0.189756  0.193418  0.186575
# ..       ...       ...       ...
# 95  0.188806  0.193116  0.191533
# 96  0.199352  0.196767  0.188936
# 97  0.189797  0.190970  0.188888
# 98  0.189628  0.188354  0.189799
# 99  0.186179  0.187812  0.187121
#
# [100 rows x 3 columns]

# %%
RED_POT_train_df = pd.concat([RED_POT_trad_train_df, RED_POT_skorch_train_df], axis = 1)
RED_POT_train_df
# Out:
#     catboost      LGBM   xgboost  skorch_1  skorch_2  skorch_3
# 0   0.097439  0.097672  0.115362  0.187553  0.185731  0.185748
# 1   0.095706  0.095866  0.115569  0.185183  0.188696  0.184692
# 2   0.096531  0.097423  0.117304  0.187439  0.190559  0.181684
# 3   0.094663  0.096009  0.122557  0.186022  0.192209  0.185410
# 4   0.102819  0.096146  0.118688  0.189756  0.193418  0.186575
# ..       ...       ...       ...       ...       ...       ...
# 95  0.098747  0.100733  0.124680  0.188806  0.193116  0.191533
# 96  0.102322  0.096265  0.122826  0.199352  0.196767  0.188936
# 97  0.097428  0.096219  0.120741  0.189797  0.190970  0.188888
# 98  0.093988  0.092564  0.117486  0.189628  0.188354  0.189799
# 99  0.094802  0.096219  0.120614  0.186179  0.187812  0.187121
#
# [100 rows x 6 columns]

# %%
RED_POT_trad_test_df = pd.read_csv('Trad_ML/Reduction_potential/RED_POT_HOLDOUT_MAE.csv')
RED_POT_trad_test_df
# Out:
#     catboost      LGBM   xgboost
# 0   0.266187  0.270716  0.274342
# 1   0.274694  0.288676  0.287372
# 2   0.252472  0.257122  0.274298
# 3   0.259243  0.270234  0.275309
# 4   0.260959  0.265576  0.277615
# ..       ...       ...       ...
# 95  0.227915  0.235820  0.257114
# 96  0.234650  0.236810  0.234773
# 97  0.254177  0.260248  0.271382
# 98  0.268305  0.271058  0.283071
# 99  0.234563  0.245686  0.255473
#
# [100 rows x 3 columns]

# %%
RED_POT_trad_test_df.describe()
# Out:
#          catboost        LGBM     xgboost
# count  100.000000  100.000000  100.000000
# mean     0.253413    0.261360    0.267179
# std      0.014796    0.015691    0.014834
# min      0.218606    0.215039    0.218891
# 25%      0.242311    0.250916    0.256828
# 50%      0.253502    0.261011    0.268380
# 75%      0.264601    0.273222    0.279146
# max      0.281204    0.296144    0.292307

# %%
RED_POT_trad_test_df = RED_POT_trad_test_df[['catboost', 'LGBM', 'xgboost']]
RED_POT_trad_test_df
# Out:
#     catboost      LGBM   xgboost
# 0   0.266187  0.270716  0.274342
# 1   0.274694  0.288676  0.287372
# 2   0.252472  0.257122  0.274298
# 3   0.259243  0.270234  0.275309
# 4   0.260959  0.265576  0.277615
# ..       ...       ...       ...
# 95  0.227915  0.235820  0.257114
# 96  0.234650  0.236810  0.234773
# 97  0.254177  0.260248  0.271382
# 98  0.268305  0.271058  0.283071
# 99  0.234563  0.245686  0.255473
#
# [100 rows x 3 columns]

# %%
RED_POT_skorch_test_df = pd.read_csv('Skorch_NN/Reduction_potential/RED_POT_HOLDOUT_MAE.csv')
RED_POT_skorch_test_df
# Out:
#     skorch_model_1  skorch_model_2  skorch_model_3
# 0         0.290075        0.292186        0.285228
# 1         0.277355        0.284055        0.282147
# 2         0.275309        0.276298        0.266952
# 3         0.273869        0.275971        0.273103
# 4         0.284716        0.281755        0.276339
# ..             ...             ...             ...
# 95        0.264894        0.265548        0.261003
# 96        0.272865        0.275111        0.260613
# 97        0.274358        0.278296        0.276331
# 98        0.303197        0.299560        0.306744
# 99        0.254379        0.246296        0.255104
#
# [100 rows x 3 columns]

# %%
RED_POT_skorch_test_df.describe()
# Out:
#        skorch_model_1  skorch_model_2  skorch_model_3
# count      100.000000      100.000000      100.000000
# mean         0.277879        0.277280        0.277816
# std          0.015174        0.015576        0.015123
# min          0.239477        0.240975        0.242880
# 25%          0.267037        0.266692        0.264834
# 50%          0.276835        0.278203        0.277234
# 75%          0.288370        0.288500        0.289366
# max          0.307302        0.312121        0.319157

# %%
RED_POT_skorch_test_df.columns = ['skorch_1', 'skorch_2', 'skorch_3']
RED_POT_skorch_test_df
# Out:
#     skorch_1  skorch_2  skorch_3
# 0   0.290075  0.292186  0.285228
# 1   0.277355  0.284055  0.282147
# 2   0.275309  0.276298  0.266952
# 3   0.273869  0.275971  0.273103
# 4   0.284716  0.281755  0.276339
# ..       ...       ...       ...
# 95  0.264894  0.265548  0.261003
# 96  0.272865  0.275111  0.260613
# 97  0.274358  0.278296  0.276331
# 98  0.303197  0.299560  0.306744
# 99  0.254379  0.246296  0.255104
#
# [100 rows x 3 columns]

# %%
RED_POT_test_df = pd.concat([RED_POT_trad_test_df, RED_POT_skorch_test_df], axis = 1)
RED_POT_test_df
# Out:
#     catboost      LGBM   xgboost  skorch_1  skorch_2  skorch_3
# 0   0.266187  0.270716  0.274342  0.290075  0.292186  0.285228
# 1   0.274694  0.288676  0.287372  0.277355  0.284055  0.282147
# 2   0.252472  0.257122  0.274298  0.275309  0.276298  0.266952
# 3   0.259243  0.270234  0.275309  0.273869  0.275971  0.273103
# 4   0.260959  0.265576  0.277615  0.284716  0.281755  0.276339
# ..       ...       ...       ...       ...       ...       ...
# 95  0.227915  0.235820  0.257114  0.264894  0.265548  0.261003
# 96  0.234650  0.236810  0.234773  0.272865  0.275111  0.260613
# 97  0.254177  0.260248  0.271382  0.274358  0.278296  0.276331
# 98  0.268305  0.271058  0.283071  0.303197  0.299560  0.306744
# 99  0.234563  0.245686  0.255473  0.254379  0.246296  0.255104
#
# [100 rows x 6 columns]

# %%
from matplotlib.ticker import FormatStrFormatter

# %%
labels = RED_POT_test_df.columns

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(30, 10))

plt.rcParams.update({'font.size': 22, 'font.weight':'bold'})
bplot1 = ax1.boxplot(RED_POT_train_df,
                     vert=True,
                     patch_artist=True,
                     labels=labels)
ax1.set_title('Training Rectangular box plot', fontsize = 24, fontweight='bold')


bplot2 = ax2.boxplot(RED_POT_test_df,
                     vert=True,
                     patch_artist=True,
                     labels=labels)
ax2.set_title('Holdout Rectangular box plot', fontsize = 24, fontweight='bold')

colors = ['red', 'blue', 'orange', 'violet', 'yellow', 'green', 'pink', 'brown', 'lightblue', 'magenta', 'lightgreen', 'cyan', 'beige']
for bplot in (bplot1, bplot2):
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)

for ax in [ax1, ax2]:
    ax.yaxis.grid(False)
    ax.xaxis.grid(False)
    ax.set_ylabel('MAE (V)', fontsize = 24, fontweight='bold')

plt.show()
