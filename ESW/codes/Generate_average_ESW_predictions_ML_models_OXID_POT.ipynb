# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pwd
# Out:
# /content

# %%
df = pd.read_csv('NEW-Oxidation_potentials_predictions_for_SCREENED_combined_dataset_of_Li-based_Na_based_K-based_Mg-based_Ba-based_Ca-based_and_Al-based_compounds_from_MPJ.csv')
df
# Out:
#       catboost_0  catboost_1  catboost_2  catboost_3  catboost_4  catboost_5  \
# 0       4.636324    3.272406    4.304734    4.033566    4.022988    4.317385
# 1       2.948711    3.001860    2.949653    2.711834    2.452330    2.660674
# 2       3.670126    3.383212    3.481568    3.654602    3.495361    3.438321
# 3       1.581037    1.266791    1.160592    1.607626    1.430729    1.326315
# 4       1.503433    1.209918    1.445782    1.456748    1.386756    1.738869
# ...          ...         ...         ...         ...         ...         ...
# 5319    3.690609    3.826576    3.822014    3.870647    3.679745    3.861137
# 5320    3.536738    3.842293    3.640215    3.739524    3.620772    3.549864
# 5321    3.716558    3.925663    3.990949    3.963077    3.791224    3.954977
# 5322    3.735878    3.813587    3.986611    4.105550    3.870662    3.901116
# 5323    3.621188    3.852725    3.776533    3.929044    3.652970    3.702153
#
# ...

# %%
df[df.columns[0:100]]
# Out:
#       catboost_0  catboost_1  catboost_2  catboost_3  catboost_4  catboost_5  \
# 0       4.636324    3.272406    4.304734    4.033566    4.022988    4.317385
# 1       2.948711    3.001860    2.949653    2.711834    2.452330    2.660674
# 2       3.670126    3.383212    3.481568    3.654602    3.495361    3.438321
# 3       1.581037    1.266791    1.160592    1.607626    1.430729    1.326315
# 4       1.503433    1.209918    1.445782    1.456748    1.386756    1.738869
# ...          ...         ...         ...         ...         ...         ...
# 5319    3.690609    3.826576    3.822014    3.870647    3.679745    3.861137
# 5320    3.536738    3.842293    3.640215    3.739524    3.620772    3.549864
# 5321    3.716558    3.925663    3.990949    3.963077    3.791224    3.954977
# 5322    3.735878    3.813587    3.986611    4.105550    3.870662    3.901116
# 5323    3.621188    3.852725    3.776533    3.929044    3.652970    3.702153
#
# ...

# %%
df[df.columns[100:200]]
# Out:
#         LGBM_0    LGBM_1    LGBM_2    LGBM_3    LGBM_4    LGBM_5    LGBM_6  \
# 0     3.948165  3.683897  3.882442  3.894894  3.845519  3.818464  3.897897
# 1     1.917518  2.687116  2.054170  2.388595  2.316207  2.328882  2.279361
# 2     3.681408  3.627881  3.163080  3.403574  3.343627  3.557686  3.186267
# 3     1.284786  1.389663  1.424787  1.428303  1.375855  1.288640  1.692946
# 4     1.124914  1.028319  1.161423  1.108259  1.347727  1.204840  1.202855
# ...        ...       ...       ...       ...       ...       ...       ...
# 5319  3.591022  3.595862  3.548654  3.678839  3.399099  3.518046  3.466621
# 5320  3.541675  3.507859  3.402180  3.589122  3.409511  3.412780  3.471801
# 5321  3.564990  3.518497  3.533228  3.630120  3.382776  3.507796  3.476273
# 5322  3.561641  3.570019  3.433972  3.662806  3.358902  3.436564  3.401764
# 5323  3.543742  3.429380  3.436037  3.594607  3.406242  3.436689  3.434395
#
# ...

# %%
df[df.columns[200:300]]
# Out:
#       xgboost_0  xgboost_1  xgboost_2  xgboost_3  xgboost_4  xgboost_5  \
# 0      4.435996   3.833308   4.203492   4.010027   4.081264   3.985854
# 1      2.413876   2.804950   2.702276   2.450137   2.214082   2.426239
# 2      3.744883   3.571364   3.414763   3.643175   3.418129   3.678158
# 3      1.274541   1.049165   1.067589   1.249781   1.346039   0.924952
# 4      1.684997   1.655191   1.199235   1.716483   1.536053   1.508263
# ...         ...        ...        ...        ...        ...        ...
# 5319   3.614867   3.784930   3.904829   3.946869   3.844808   3.818605
# 5320   3.479325   3.630511   3.595514   3.866347   3.678651   3.653288
# 5321   3.583892   3.756771   3.921336   4.012090   3.865795   3.774003
# 5322   3.540860   3.587496   3.752353   3.857108   3.788284   3.753324
# 5323   3.536160   3.636524   3.719958   4.003358   3.646203   3.690784
#
#       xgboost_6  xgboost_7  xgboost_8  xgboost_9  ...  xgboost_90  xgboost_91  \
# ...

# %%
# ['catboost', 'LGBM', 'xgboost']
catboost = df[df.columns[0:100]]
LGBM = df[df.columns[100:200]]
xgboost = df[df.columns[200:300]]

# %%
model_list_names = ['catboost', 'LGBM', 'xgboost']

# %%
model_list = [catboost, LGBM, xgboost]

# %%
len(model_list)
# Out:
# 3

# %%
len(model_list_names)
# Out:
# 3

# %%
for i in range(len(model_list)):
    print(model_list[i].columns)
    print()
    print('-------------------')
    print()
# Out:
# Index(['catboost_0', 'catboost_1', 'catboost_2', 'catboost_3', 'catboost_4',
#        'catboost_5', 'catboost_6', 'catboost_7', 'catboost_8', 'catboost_9',
#        'catboost_10', 'catboost_11', 'catboost_12', 'catboost_13',
#        'catboost_14', 'catboost_15', 'catboost_16', 'catboost_17',
#        'catboost_18', 'catboost_19', 'catboost_20', 'catboost_21',
#        'catboost_22', 'catboost_23', 'catboost_24', 'catboost_25',
#        'catboost_26', 'catboost_27', 'catboost_28', 'catboost_29',
#        'catboost_30', 'catboost_31', 'catboost_32', 'catboost_33',
#        'catboost_34', 'catboost_35', 'catboost_36', 'catboost_37',
#        'catboost_38', 'catboost_39', 'catboost_40', 'catboost_41',
#        'catboost_42', 'catboost_43', 'catboost_44', 'catboost_45',
#        'catboost_46', 'catboost_47', 'catboost_48', 'catboost_49',
#        'catboost_50', 'catboost_51', 'catboost_52', 'catboost_53',
#        'catboost_54', 'catboost_55', 'catboost_56', 'catboost_57',
# ...

# %%
for i in range(len(model_list)):
    model_list[i][model_list_names[i] + '_Average_prediction'] = model_list[i].mean(axis=1)
    print(model_list[i][[model_list_names[i] + '_Average_prediction']])
    print()
    print('-------------------')
    print()
# Out:
#       catboost_Average_prediction
# 0                        4.030779
# 1                        2.833155
# 2                        3.593707
# 3                        1.410993
# 4                        1.531216
# ...                           ...
# 5319                     3.803261
# 5320                     3.639611
# 5321                     3.854355
# 5322                     3.880128
# 5323                     3.700561
#
# [5324 rows x 1 columns]
#
# -------------------
#
#       LGBM_Average_prediction
# 0                    3.710582
# 1                    2.282456
# 2                    3.447293
# 3                    1.360334
# 4                    1.263694
# ...                       ...
# 5319                 3.496951
# 5320                 3.445936
# 5321                 3.474998
# 5322                 3.487675
# 5323                 3.437447
#
# [5324 rows x 1 columns]
#
# -------------------
#
#       xgboost_Average_prediction
# 0                       3.914680
# ...

# %%
for i in range(len(model_list)):
  print(len(model_list[i].columns))
# Out:
# 101
# 101
# 101

# %%
for i in range(len(model_list)):
  print(model_list[i][model_list[i].columns[-1]])
  print()
  print('-------------------')
  print()
# Out:
# 0       4.030779
# 1       2.833155
# 2       3.593707
# 3       1.410993
# 4       1.531216
#           ...
# 5319    3.803261
# 5320    3.639611
# 5321    3.854355
# 5322    3.880128
# 5323    3.700561
# Name: catboost_Average_prediction, Length: 5324, dtype: float64
#
# -------------------
#
# 0       3.710582
# 1       2.282456
# 2       3.447293
# 3       1.360334
# 4       1.263694
#           ...
# 5319    3.496951
# 5320    3.445936
# 5321    3.474998
# 5322    3.487675
# 5323    3.437447
# Name: LGBM_Average_prediction, Length: 5324, dtype: float64
#
# -------------------
#
# 0       3.914680
# 1       2.601111
# 2       3.599447
# 3       1.130451
# 4       1.470256
#           ...
# 5319    3.825055
# 5320    3.661647
# 5321    3.794539
# 5322    3.675276
# 5323    3.718230
# Name: xgboost_Average_prediction, Length: 5324, dtype: float64
#
# -------------------

# %%
for i in range(len(model_list)):
  model_list[i].to_csv(model_list_names[i] + '.csv', index=False)

# %%
pd.read_csv(model_list_names[0] + '.csv')
# Out:
#       catboost_0  catboost_1  catboost_2  catboost_3  catboost_4  catboost_5  \
# 0       4.636324    3.272406    4.304734    4.033566    4.022988    4.317385
# 1       2.948711    3.001860    2.949653    2.711834    2.452330    2.660674
# 2       3.670126    3.383212    3.481568    3.654602    3.495361    3.438321
# 3       1.581037    1.266791    1.160592    1.607626    1.430729    1.326315
# 4       1.503433    1.209918    1.445782    1.456748    1.386756    1.738869
# ...          ...         ...         ...         ...         ...         ...
# 5319    3.690609    3.826576    3.822014    3.870647    3.679745    3.861137
# 5320    3.536738    3.842293    3.640215    3.739524    3.620772    3.549864
# 5321    3.716558    3.925663    3.990949    3.963077    3.791224    3.954977
# 5322    3.735878    3.813587    3.986611    4.105550    3.870662    3.901116
# 5323    3.621188    3.852725    3.776533    3.929044    3.652970    3.702153
#
# ...

# %%
pd.read_csv(model_list_names[1] + '.csv')
# Out:
#         LGBM_0    LGBM_1    LGBM_2    LGBM_3    LGBM_4    LGBM_5    LGBM_6  \
# 0     3.948165  3.683897  3.882442  3.894894  3.845519  3.818464  3.897897
# 1     1.917518  2.687116  2.054170  2.388595  2.316207  2.328882  2.279361
# 2     3.681408  3.627881  3.163080  3.403574  3.343627  3.557686  3.186267
# 3     1.284786  1.389663  1.424787  1.428303  1.375855  1.288640  1.692946
# 4     1.124914  1.028319  1.161423  1.108259  1.347727  1.204840  1.202855
# ...        ...       ...       ...       ...       ...       ...       ...
# 5319  3.591022  3.595862  3.548654  3.678839  3.399099  3.518046  3.466621
# 5320  3.541675  3.507859  3.402180  3.589122  3.409511  3.412780  3.471801
# 5321  3.564990  3.518497  3.533228  3.630120  3.382776  3.507796  3.476273
# 5322  3.561641  3.570019  3.433972  3.662806  3.358902  3.436564  3.401764
# 5323  3.543742  3.429380  3.436037  3.594607  3.406242  3.436689  3.434395
#
# ...

# %%
model_list[0][model_list[0].columns[-1]]
# Out:
# 0       4.030779
# 1       2.833155
# 2       3.593707
# 3       1.410993
# 4       1.531216
#           ...
# 5319    3.803261
# 5320    3.639611
# 5321    3.854355
# 5322    3.880128
# 5323    3.700561
# Name: catboost_Average_prediction, Length: 5324, dtype: float64

# %%
df2 = pd.read_csv('Combined_dataset_of_SCREENED_Li-based_Na_based_K-based_Mg-based_Ba-based_Ca-based_and_Al-based_compounds_from_MPJ_for_ESW_predictions_16_July_2025.csv')
df2
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 3        mp-3887  emmet_version='0.72.20' pymatgen_version='2023...      48
# 4        mp-3949  emmet_version='0.72.20' pymatgen_version='2023...      64
# ...          ...                                                ...     ...
# 5319  mp-2712854  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5320  mp-2712928  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5321  mp-2713730  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5322  mp-2713752  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5323  mp-2713949  emmet_version='0.72.20' pymatgen_version='2023...     102
#
# ...

# %%
for i in range(len(model_list)):
  df2 = pd.concat([df2, model_list[i][model_list[i].columns[-1]]], axis = 1)

df2
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 3        mp-3887  emmet_version='0.72.20' pymatgen_version='2023...      48
# 4        mp-3949  emmet_version='0.72.20' pymatgen_version='2023...      64
# ...          ...                                                ...     ...
# 5319  mp-2712854  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5320  mp-2712928  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5321  mp-2713730  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5322  mp-2713752  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5323  mp-2713949  emmet_version='0.72.20' pymatgen_version='2023...     102
#
# ...

# %%
df2.to_csv('NEW_Average_ML_model_predictions_for_OXID_POT_18_July_2025.csv', index=False)
# !head NEW_Average_ML_model_predictions_for_OXID_POT_18_July_2025.csv
# Out:
# material_id,builder_meta,nsites,elements,nelements,composition_reduced,formula_pretty,formula_anonymous,chemsys,volume,density,density_atomic,symmetry,property_name,deprecated,deprecation_reasons,last_updated,origins,warnings,task_ids,uncorrected_energy_per_atom,energy_per_atom,formation_energy_per_atom,energy_above_hull,is_stable,equilibrium_reaction_energy_per_atom,decomposes_to,xas,grain_boundaries,band_gap,cbm,vbm,efermi,is_gap_direct,is_metal,es_source_calc_id,bandstructure,dos,dos_energy_up,dos_energy_down,is_magnetic,ordering,total_magnetization,total_magnetization_normalized_vol,total_magnetization_normalized_formula_units,num_magnetic_sites,num_unique_magnetic_sites,types_of_magnetic_species,bulk_modulus,shear_modulus,universal_anisotropy,homogeneous_poisson,e_total,e_ionic,e_electronic,n,e_ij_max,weighted_surface_energy_EV_PER_ANG2,weighted_surface_energy,weighted_work_function,surface_anisotropy,shape_factor,has_reconstructed,possible_species,has_props,theoretical,database
# ...
