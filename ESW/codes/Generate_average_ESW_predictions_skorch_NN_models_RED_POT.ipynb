# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pwd
# Out:
# /content

# %%
df = pd.read_csv('NEW-Reduction_potentials_predictions_for_SCREENED_combined_dataset_of_Li-based_Na_based_K-based_Mg-based_Ba-based_Ca-based_and_Al-based_compounds_from_MPJ.csv')
df
# Out:
#       skorch_model_1_0  skorch_model_1_1  skorch_model_1_2  skorch_model_1_3  \
# 0             1.072028          0.679647          0.955206          0.828422
# 1             3.283154          3.417685          3.289475          3.272772
# 2             0.438243          0.658827          0.417476          0.402663
# 3             0.288905          0.427558          0.294994          0.207899
# 4             0.679844          1.094461          0.622462          0.681543
# ...                ...               ...               ...               ...
# 5319          2.315424          2.192616          2.132001          2.773009
# 5320          2.240312          2.263395          2.245771          2.848942
# 5321          2.237755          2.166991          2.020119          2.632928
# 5322          1.426441          1.328406          1.379637          1.402512
# 5323          2.177832          2.191250          2.139591          2.755207
#
# ...

# %%
skorch_model_1 = df[df.columns[0:100]]
skorch_model_2 = df[df.columns[100:200]]
skorch_model_3 = df[df.columns[200:300]]

# %%
model_list_names = ['skorch_model_1', 'skorch_model_2', 'skorch_model_3']

# %%
model_list = [skorch_model_1, skorch_model_2, skorch_model_3]

# %%
for i in range(len(model_list)):
    print(model_list[i].columns)
    print()
    print('-------------------')
    print()
# Out:
# Index(['skorch_model_1_0', 'skorch_model_1_1', 'skorch_model_1_2',
#        'skorch_model_1_3', 'skorch_model_1_4', 'skorch_model_1_5',
#        'skorch_model_1_6', 'skorch_model_1_7', 'skorch_model_1_8',
#        'skorch_model_1_9', 'skorch_model_1_10', 'skorch_model_1_11',
#        'skorch_model_1_12', 'skorch_model_1_13', 'skorch_model_1_14',
#        'skorch_model_1_15', 'skorch_model_1_16', 'skorch_model_1_17',
#        'skorch_model_1_18', 'skorch_model_1_19', 'skorch_model_1_20',
#        'skorch_model_1_21', 'skorch_model_1_22', 'skorch_model_1_23',
#        'skorch_model_1_24', 'skorch_model_1_25', 'skorch_model_1_26',
#        'skorch_model_1_27', 'skorch_model_1_28', 'skorch_model_1_29',
#        'skorch_model_1_30', 'skorch_model_1_31', 'skorch_model_1_32',
#        'skorch_model_1_33', 'skorch_model_1_34', 'skorch_model_1_35',
#        'skorch_model_1_36', 'skorch_model_1_37', 'skorch_model_1_38',
#        'skorch_model_1_39', 'skorch_model_1_40', 'skorch_model_1_41',
# ...

# %%
for i in range(len(model_list)):
    model_list[i][model_list_names[i] + '_Average_prediction'] = model_list[i].mean(axis=1)
    print(model_list[i][[model_list_names[i] + '_Average_prediction']])
    print()
    print('-------------------')
    print()
# Out:
#       skorch_model_1_Average_prediction
# 0                              0.945365
# 1                              3.651265
# 2                              0.454968
# 3                              0.243985
# 4                              1.330032
# ...                                 ...
# 5319                           2.340688
# 5320                           2.370447
# 5321                           2.227494
# 5322                           1.353408
# 5323                           2.249604
#
# [5324 rows x 1 columns]
#
# -------------------
#
#       skorch_model_2_Average_prediction
# 0                              0.913073
# 1                              3.646454
# 2                              0.447746
# 3                              0.255551
# 4                              1.340203
# ...                                 ...
# 5319                           2.348494
# 5320                           2.371071
# 5321                           2.243552
# ...

# %%
for i in range(len(model_list)):
  print(len(model_list[i].columns))
# Out:
# 101
# 101
# 101

# %%
for i in range(len(model_list)):
  print(model_list[i][model_list[i].columns[-1]])
  print()
  print('-------------------')
  print()
# Out:
# 0       0.945365
# 1       3.651265
# 2       0.454968
# 3       0.243985
# 4       1.330032
#           ...
# 5319    2.340688
# 5320    2.370447
# 5321    2.227494
# 5322    1.353408
# 5323    2.249604
# Name: skorch_model_1_Average_prediction, Length: 5324, dtype: float64
#
# -------------------
#
# 0       0.913073
# 1       3.646454
# 2       0.447746
# 3       0.255551
# 4       1.340203
#           ...
# 5319    2.348494
# 5320    2.371071
# 5321    2.243552
# 5322    1.374967
# 5323    2.253828
# Name: skorch_model_2_Average_prediction, Length: 5324, dtype: float64
#
# -------------------
#
# 0       0.925817
# 1       3.744238
# 2       0.440996
# 3       0.259583
# 4       1.341518
#           ...
# 5319    2.361998
# 5320    2.384026
# 5321    2.255841
# 5322    1.372546
# 5323    2.261354
# Name: skorch_model_3_Average_prediction, Length: 5324, dtype: float64
#
# -------------------

# %%
for i in range(len(model_list)):
  model_list[i].to_csv(model_list_names[i] + '.csv', index=False)

# %%
pd.read_csv(model_list_names[0] + '.csv')
# Out:
#       skorch_model_1_0  skorch_model_1_1  skorch_model_1_2  skorch_model_1_3  \
# 0             1.072028          0.679647          0.955206          0.828422
# 1             3.283154          3.417685          3.289475          3.272772
# 2             0.438243          0.658827          0.417476          0.402663
# 3             0.288905          0.427558          0.294994          0.207899
# 4             0.679844          1.094461          0.622462          0.681543
# ...                ...               ...               ...               ...
# 5319          2.315424          2.192616          2.132001          2.773009
# 5320          2.240312          2.263395          2.245771          2.848942
# 5321          2.237755          2.166991          2.020119          2.632928
# 5322          1.426441          1.328406          1.379637          1.402512
# 5323          2.177832          2.191250          2.139591          2.755207
#
# ...

# %%
df2 = pd.read_csv('ESW_validation_dataset.csv')
df2
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 3        mp-3887  emmet_version='0.72.20' pymatgen_version='2023...      48
# 4        mp-3949  emmet_version='0.72.20' pymatgen_version='2023...      64
# ...          ...                                                ...     ...
# 5319  mp-2712854  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5320  mp-2712928  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5321  mp-2713730  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5322  mp-2713752  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5323  mp-2713949  emmet_version='0.72.20' pymatgen_version='2023...     102
#
# ...

# %%
for i in range(len(model_list)):
  df2 = pd.concat([df2, model_list[i][model_list[i].columns[-1]]], axis = 1)

df2
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 3        mp-3887  emmet_version='0.72.20' pymatgen_version='2023...      48
# 4        mp-3949  emmet_version='0.72.20' pymatgen_version='2023...      64
# ...          ...                                                ...     ...
# 5319  mp-2712854  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5320  mp-2712928  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5321  mp-2713730  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5322  mp-2713752  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5323  mp-2713949  emmet_version='0.72.20' pymatgen_version='2023...     102
#
# ...

# %%
df2.to_csv('NEW_Average_skorch_NN_model_predictions_for_RED_POT.csv', index=False)
# !head NEW_Average_skorch_NN_model_predictions_for_RED_POT.csv
# Out:
# material_id,builder_meta,nsites,elements,nelements,composition_reduced,formula_pretty,formula_anonymous,chemsys,volume,density,density_atomic,symmetry,property_name,deprecated,deprecation_reasons,last_updated,origins,warnings,task_ids,uncorrected_energy_per_atom,energy_per_atom,formation_energy_per_atom,energy_above_hull,is_stable,equilibrium_reaction_energy_per_atom,decomposes_to,xas,grain_boundaries,band_gap,cbm,vbm,efermi,is_gap_direct,is_metal,es_source_calc_id,bandstructure,dos,dos_energy_up,dos_energy_down,is_magnetic,ordering,total_magnetization,total_magnetization_normalized_vol,total_magnetization_normalized_formula_units,num_magnetic_sites,num_unique_magnetic_sites,types_of_magnetic_species,bulk_modulus,shear_modulus,universal_anisotropy,homogeneous_poisson,e_total,e_ionic,e_electronic,n,e_ij_max,weighted_surface_energy_EV_PER_ANG2,weighted_surface_energy,weighted_work_function,surface_anisotropy,shape_factor,has_reconstructed,possible_species,has_props,theoretical,database
# ...
