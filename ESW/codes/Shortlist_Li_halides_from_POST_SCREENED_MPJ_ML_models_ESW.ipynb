# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pwd
# Out:
# /content

# %%
df = pd.read_csv('Combined_dataset_of_SCREENED_Li-based_Na_based_K-based_Mg-based_Ba-based_Ca-based_and_Al-based_compounds_from_MPJ_for_ESW_predictions_16_July_2025.csv')
df
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 3        mp-3887  emmet_version='0.72.20' pymatgen_version='2023...      48
# 4        mp-3949  emmet_version='0.72.20' pymatgen_version='2023...      64
# ...          ...                                                ...     ...
# 5319  mp-2712854  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5320  mp-2712928  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5321  mp-2713730  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5322  mp-2713752  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5323  mp-2713949  emmet_version='0.72.20' pymatgen_version='2023...     102
#
# ...

# %%
df1 = pd.read_csv('NEW_Average_ML_model_predictions_for_RED_POT_18_July_2025.csv')
df1
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 3        mp-3887  emmet_version='0.72.20' pymatgen_version='2023...      48
# 4        mp-3949  emmet_version='0.72.20' pymatgen_version='2023...      64
# ...          ...                                                ...     ...
# 5319  mp-2712854  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5320  mp-2712928  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5321  mp-2713730  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5322  mp-2713752  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5323  mp-2713949  emmet_version='0.72.20' pymatgen_version='2023...     102
#
# ...

# %%
df2 = pd.read_csv('NEW_Average_ML_model_predictions_for_OXID_POT_18_July_2025.csv')
df2
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 3        mp-3887  emmet_version='0.72.20' pymatgen_version='2023...      48
# 4        mp-3949  emmet_version='0.72.20' pymatgen_version='2023...      64
# ...          ...                                                ...     ...
# 5319  mp-2712854  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5320  mp-2712928  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5321  mp-2713730  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5322  mp-2713752  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5323  mp-2713949  emmet_version='0.72.20' pymatgen_version='2023...     102
#
# ...

# %%
new_df = pd.concat([df, df1[['catboost_Average_prediction', 'LGBM_Average_prediction', 'xgboost_Average_prediction']]], axis = 1)
new_df
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 3        mp-3887  emmet_version='0.72.20' pymatgen_version='2023...      48
# 4        mp-3949  emmet_version='0.72.20' pymatgen_version='2023...      64
# ...          ...                                                ...     ...
# 5319  mp-2712854  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5320  mp-2712928  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5321  mp-2713730  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5322  mp-2713752  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5323  mp-2713949  emmet_version='0.72.20' pymatgen_version='2023...     102
#
# ...

# %%
new_df[['catboost_RED_POT_Average_prediction', 'LGBM_RED_POT_Average_prediction', 'xgboost_RED_POT_Average_prediction']] = new_df[['catboost_Average_prediction', 'LGBM_Average_prediction', 'xgboost_Average_prediction']]
new_df
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 3        mp-3887  emmet_version='0.72.20' pymatgen_version='2023...      48
# 4        mp-3949  emmet_version='0.72.20' pymatgen_version='2023...      64
# ...          ...                                                ...     ...
# 5319  mp-2712854  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5320  mp-2712928  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5321  mp-2713730  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5322  mp-2713752  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5323  mp-2713949  emmet_version='0.72.20' pymatgen_version='2023...     102
#
# ...

# %%
new_df = new_df.drop(['catboost_Average_prediction', 'LGBM_Average_prediction', 'xgboost_Average_prediction'], axis = 1)
new_df
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 3        mp-3887  emmet_version='0.72.20' pymatgen_version='2023...      48
# 4        mp-3949  emmet_version='0.72.20' pymatgen_version='2023...      64
# ...          ...                                                ...     ...
# 5319  mp-2712854  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5320  mp-2712928  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5321  mp-2713730  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5322  mp-2713752  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5323  mp-2713949  emmet_version='0.72.20' pymatgen_version='2023...     102
#
# ...

# %%
new_df = pd.concat([new_df, df2[['catboost_Average_prediction', 'LGBM_Average_prediction', 'xgboost_Average_prediction']]], axis = 1)
new_df
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 3        mp-3887  emmet_version='0.72.20' pymatgen_version='2023...      48
# 4        mp-3949  emmet_version='0.72.20' pymatgen_version='2023...      64
# ...          ...                                                ...     ...
# 5319  mp-2712854  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5320  mp-2712928  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5321  mp-2713730  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5322  mp-2713752  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5323  mp-2713949  emmet_version='0.72.20' pymatgen_version='2023...     102
#
# ...

# %%
new_df[['catboost_OXID_POT_Average_prediction', 'LGBM_OXID_POT_Average_prediction', 'xgboost_OXID_POT_Average_prediction']] = new_df[['catboost_Average_prediction', 'LGBM_Average_prediction', 'xgboost_Average_prediction']]
new_df
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 3        mp-3887  emmet_version='0.72.20' pymatgen_version='2023...      48
# 4        mp-3949  emmet_version='0.72.20' pymatgen_version='2023...      64
# ...          ...                                                ...     ...
# 5319  mp-2712854  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5320  mp-2712928  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5321  mp-2713730  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5322  mp-2713752  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5323  mp-2713949  emmet_version='0.72.20' pymatgen_version='2023...     102
#
# ...

# %%
new_df = new_df.drop(['catboost_Average_prediction', 'LGBM_Average_prediction', 'xgboost_Average_prediction'], axis = 1)
new_df
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 3        mp-3887  emmet_version='0.72.20' pymatgen_version='2023...      48
# 4        mp-3949  emmet_version='0.72.20' pymatgen_version='2023...      64
# ...          ...                                                ...     ...
# 5319  mp-2712854  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5320  mp-2712928  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5321  mp-2713730  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5322  mp-2713752  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5323  mp-2713949  emmet_version='0.72.20' pymatgen_version='2023...     102
#
# ...

# %%
new_df[['catboost_RED_POT_Average_prediction', 'LGBM_RED_POT_Average_prediction', 'xgboost_RED_POT_Average_prediction']].describe()
# Out:
#        catboost_RED_POT_Average_prediction  LGBM_RED_POT_Average_prediction  \
# count                          5324.000000                      5324.000000
# mean                              1.456574                         1.400122
# std                               0.798623                         0.787662
# min                              -0.133111                        -0.185656
# 25%                               0.884589                         0.812733
# 50%                               1.405962                         1.330815
# 75%                               2.011558                         1.956041
# max                               3.668622                         3.749892
#
#        xgboost_RED_POT_Average_prediction
# count                         5324.000000
# mean                             1.398474
# std                              0.770805
# min                             -0.096174
# 25%                              0.836711
# ...

# %%
new_df[['catboost_OXID_POT_Average_prediction', 'LGBM_OXID_POT_Average_prediction', 'xgboost_OXID_POT_Average_prediction']].describe()
# Out:
#        catboost_OXID_POT_Average_prediction  LGBM_OXID_POT_Average_prediction  \
# count                           5324.000000                       5324.000000
# mean                               3.613968                          3.583290
# std                                1.113877                          1.109017
# min                                0.106536                          0.529175
# 25%                                2.949688                          2.747735
# 50%                                3.733030                          3.727377
# 75%                                4.337401                          4.358838
# max                                7.095438                          7.021721
#
#        xgboost_OXID_POT_Average_prediction
# count                          5324.000000
# mean                              3.608012
# std                               1.114581
# min                               0.328968
# 25%                               2.917152
# ...

# %%
new_df = new_df[new_df['catboost_OXID_POT_Average_prediction'] >= 4.0]
new_df = new_df[new_df['LGBM_OXID_POT_Average_prediction'] >= 4.0]
new_df = new_df[new_df['xgboost_OXID_POT_Average_prediction'] >= 4.0]

# %%
new_df
# Out:
#      material_id                                       builder_meta  nsites  \
# 6        mp-4855  emmet_version='0.72.20' pymatgen_version='2023...      42
# 8        mp-6134  emmet_version='0.72.20' pymatgen_version='2023...      18
# 9        mp-6253  emmet_version='0.72.20' pymatgen_version='2023...      14
# 11       mp-6591  emmet_version='0.72.20' pymatgen_version='2023...      18
# 13       mp-6844  emmet_version='0.72.20' pymatgen_version='2023...      96
# ...          ...                                                ...     ...
# 5245  mp-1209303  emmet_version='0.72.20' pymatgen_version='2023...      12
# 5259  mp-1214948  emmet_version='0.72.20' pymatgen_version='2023...      56
# 5301  mp-1229117  emmet_version='0.72.20' pymatgen_version='2023...      64
# 5310  mp-1247815  emmet_version='0.72.20' pymatgen_version='2023...      64
# 5316  mp-1253073  emmet_version='0.72.20' pymatgen_version='2023...       7
#
# ...

# %%
new_df[['catboost_RED_POT_Average_prediction', 'LGBM_RED_POT_Average_prediction', 'xgboost_RED_POT_Average_prediction', 'catboost_OXID_POT_Average_prediction', 'LGBM_OXID_POT_Average_prediction', 'xgboost_OXID_POT_Average_prediction']].describe()
# Out:
#        catboost_RED_POT_Average_prediction  LGBM_RED_POT_Average_prediction  \
# count                          1889.000000                      1889.000000
# mean                              2.111976                         2.054256
# std                               0.708098                         0.690363
# min                              -0.036035                        -0.015293
# 25%                               1.671307                         1.655700
# 50%                               2.150947                         2.097718
# 75%                               2.640970                         2.534693
# max                               3.668622                         3.749892
#
#        xgboost_RED_POT_Average_prediction  \
# count                         1889.000000
# mean                             2.051103
# std                              0.673062
# min                              0.009454
# 25%                              1.629394
# ...

# %%
new_df['catboost_ESW'] = new_df['catboost_OXID_POT_Average_prediction'] - new_df['catboost_RED_POT_Average_prediction']
new_df
# Out:
#      material_id                                       builder_meta  nsites  \
# 6        mp-4855  emmet_version='0.72.20' pymatgen_version='2023...      42
# 8        mp-6134  emmet_version='0.72.20' pymatgen_version='2023...      18
# 9        mp-6253  emmet_version='0.72.20' pymatgen_version='2023...      14
# 11       mp-6591  emmet_version='0.72.20' pymatgen_version='2023...      18
# 13       mp-6844  emmet_version='0.72.20' pymatgen_version='2023...      96
# ...          ...                                                ...     ...
# 5245  mp-1209303  emmet_version='0.72.20' pymatgen_version='2023...      12
# 5259  mp-1214948  emmet_version='0.72.20' pymatgen_version='2023...      56
# 5301  mp-1229117  emmet_version='0.72.20' pymatgen_version='2023...      64
# 5310  mp-1247815  emmet_version='0.72.20' pymatgen_version='2023...      64
# 5316  mp-1253073  emmet_version='0.72.20' pymatgen_version='2023...       7
#
# ...

# %%
new_df['LGBM_ESW'] = new_df['LGBM_OXID_POT_Average_prediction'] - new_df['LGBM_RED_POT_Average_prediction']
new_df
# Out:
#      material_id                                       builder_meta  nsites  \
# 6        mp-4855  emmet_version='0.72.20' pymatgen_version='2023...      42
# 8        mp-6134  emmet_version='0.72.20' pymatgen_version='2023...      18
# 9        mp-6253  emmet_version='0.72.20' pymatgen_version='2023...      14
# 11       mp-6591  emmet_version='0.72.20' pymatgen_version='2023...      18
# 13       mp-6844  emmet_version='0.72.20' pymatgen_version='2023...      96
# ...          ...                                                ...     ...
# 5245  mp-1209303  emmet_version='0.72.20' pymatgen_version='2023...      12
# 5259  mp-1214948  emmet_version='0.72.20' pymatgen_version='2023...      56
# 5301  mp-1229117  emmet_version='0.72.20' pymatgen_version='2023...      64
# 5310  mp-1247815  emmet_version='0.72.20' pymatgen_version='2023...      64
# 5316  mp-1253073  emmet_version='0.72.20' pymatgen_version='2023...       7
#
# ...

# %%
new_df['xgboost_ESW'] = new_df['xgboost_OXID_POT_Average_prediction'] - new_df['xgboost_RED_POT_Average_prediction']
new_df
# Out:
#      material_id                                       builder_meta  nsites  \
# 6        mp-4855  emmet_version='0.72.20' pymatgen_version='2023...      42
# 8        mp-6134  emmet_version='0.72.20' pymatgen_version='2023...      18
# 9        mp-6253  emmet_version='0.72.20' pymatgen_version='2023...      14
# 11       mp-6591  emmet_version='0.72.20' pymatgen_version='2023...      18
# 13       mp-6844  emmet_version='0.72.20' pymatgen_version='2023...      96
# ...          ...                                                ...     ...
# 5245  mp-1209303  emmet_version='0.72.20' pymatgen_version='2023...      12
# 5259  mp-1214948  emmet_version='0.72.20' pymatgen_version='2023...      56
# 5301  mp-1229117  emmet_version='0.72.20' pymatgen_version='2023...      64
# 5310  mp-1247815  emmet_version='0.72.20' pymatgen_version='2023...      64
# 5316  mp-1253073  emmet_version='0.72.20' pymatgen_version='2023...       7
#
# ...

# %%
new_df[['catboost_RED_POT_Average_prediction', 'LGBM_RED_POT_Average_prediction', 'xgboost_RED_POT_Average_prediction', 'catboost_OXID_POT_Average_prediction', 'LGBM_OXID_POT_Average_prediction', 'xgboost_OXID_POT_Average_prediction']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1889 entries, 6 to 5316
# Data columns (total 6 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   catboost_RED_POT_Average_prediction   1889 non-null   float64
#  1   LGBM_RED_POT_Average_prediction       1889 non-null   float64
#  2   xgboost_RED_POT_Average_prediction    1889 non-null   float64
#  3   catboost_OXID_POT_Average_prediction  1889 non-null   float64
#  4   LGBM_OXID_POT_Average_prediction      1889 non-null   float64
#  5   xgboost_OXID_POT_Average_prediction   1889 non-null   float64
# dtypes: float64(6)
# memory usage: 103.3 KB

# %%
new_df = new_df[new_df['catboost_ESW'] >= 4.0]
new_df = new_df[new_df['LGBM_ESW'] >= 4.0]
new_df = new_df[new_df['xgboost_ESW'] >= 4.0]

# %%
new_df
# Out:
#      material_id                                       builder_meta  nsites  \
# 8        mp-6134  emmet_version='0.72.20' pymatgen_version='2023...      18
# 9        mp-6253  emmet_version='0.72.20' pymatgen_version='2023...      14
# 11       mp-6591  emmet_version='0.72.20' pymatgen_version='2023...      18
# 29       mp-9839  emmet_version='0.72.20' pymatgen_version='2023...      10
# 32      mp-10250  emmet_version='0.72.20' pymatgen_version='2023...       5
# ...          ...                                                ...     ...
# 5025   mp-540653  emmet_version='0.72.20' pymatgen_version='2023...      56
# 5035   mp-555507  emmet_version='0.72.20' pymatgen_version='2023...      76
# 5183  mp-1113633  emmet_version='0.72.20' pymatgen_version='2023...      10
# 5226  mp-1200608  emmet_version='0.72.20' pymatgen_version='2023...     224
# 5240  mp-1208679  emmet_version='0.72.20' pymatgen_version='2023...      54
#
# ...

# %%
new_df_Li = new_df[new_df['Li'] != 0]
new_df_Li
# Out:
#     material_id                                       builder_meta  nsites  \
# 8       mp-6134  emmet_version='0.72.20' pymatgen_version='2023...      18
# 9       mp-6253  emmet_version='0.72.20' pymatgen_version='2023...      14
# 11      mp-6591  emmet_version='0.72.20' pymatgen_version='2023...      18
# 29      mp-9839  emmet_version='0.72.20' pymatgen_version='2023...      10
# 32     mp-10250  emmet_version='0.72.20' pymatgen_version='2023...       5
# 40     mp-15549  emmet_version='0.72.20' pymatgen_version='2023...      20
# 47     mp-22905  emmet_version='0.72.20' pymatgen_version='2023...       2
# 67     mp-24199  emmet_version='0.72.20' pymatgen_version='2023...       4
# 166   mp-555591  emmet_version='0.72.20' pymatgen_version='2023...      36
# 174   mp-556996  emmet_version='0.72.20' pymatgen_version='2023...      30
# 402   mp-989504  emmet_version='0.72.20' pymatgen_version='2023...      10
# ...

# %%
new_df_Li[new_df_Li['F'] != 0]
# Out:
#     material_id                                       builder_meta  nsites  \
# 8       mp-6134  emmet_version='0.72.20' pymatgen_version='2023...      18
# 9       mp-6253  emmet_version='0.72.20' pymatgen_version='2023...      14
# 11      mp-6591  emmet_version='0.72.20' pymatgen_version='2023...      18
# 29      mp-9839  emmet_version='0.72.20' pymatgen_version='2023...      10
# 32     mp-10250  emmet_version='0.72.20' pymatgen_version='2023...       5
# 40     mp-15549  emmet_version='0.72.20' pymatgen_version='2023...      20
# 67     mp-24199  emmet_version='0.72.20' pymatgen_version='2023...       4
# 166   mp-555591  emmet_version='0.72.20' pymatgen_version='2023...      36
# 174   mp-556996  emmet_version='0.72.20' pymatgen_version='2023...      30
# 402   mp-989504  emmet_version='0.72.20' pymatgen_version='2023...      10
# 497  mp-1113747  emmet_version='0.72.20' pymatgen_version='2023...      10
# ...

# %%
new_df_Li[new_df_Li['Cl'] != 0]
# Out:
#     material_id                                       builder_meta  nsites  \
# 47     mp-22905  emmet_version='0.72.20' pymatgen_version='2023...       2
# 562  mp-1185319  emmet_version='0.72.20' pymatgen_version='2023...       4
#
#                      elements  nelements composition_reduced formula_pretty  \
# 47   [Element Cl, Element Li]          2             Li1 Cl1           LiCl
# 562  [Element Cl, Element Li]          2             Li1 Cl1           LiCl
#
#     formula_anonymous chemsys     volume  ...  exists  \
# 47                 AB   Cl-Li  32.856352  ...   False
# 562                AB   Cl-Li  84.810010  ...   False
#
#      catboost_RED_POT_Average_prediction LGBM_RED_POT_Average_prediction  \
# 47                              0.280778                        0.088034
# 562                             0.280778                        0.088034
#
#     xgboost_RED_POT_Average_prediction  catboost_OXID_POT_Average_prediction  \
# ...

# %%
new_df_Li[new_df_Li['Br'] != 0]
# Out:
# Empty DataFrame
# ...

# %%
new_df_Li[new_df_Li['I'] != 0]
# Out:
# Empty DataFrame
# ...

# %%
new_df_Li[new_df_Li['At'] != 0]
# Out:
# Empty DataFrame
# ...

# %%
new_df_Li_halide_4V = pd.concat([new_df_Li[new_df_Li['F'] != 0], new_df_Li[new_df_Li['Cl'] != 0], new_df_Li[new_df_Li['Br'] != 0], new_df_Li[new_df_Li['I'] != 0], new_df_Li[new_df_Li['At'] != 0]], axis = 0)
new_df_Li_halide_4V
# Out:
#     material_id                                       builder_meta  nsites  \
# 8       mp-6134  emmet_version='0.72.20' pymatgen_version='2023...      18
# 9       mp-6253  emmet_version='0.72.20' pymatgen_version='2023...      14
# 11      mp-6591  emmet_version='0.72.20' pymatgen_version='2023...      18
# 29      mp-9839  emmet_version='0.72.20' pymatgen_version='2023...      10
# 32     mp-10250  emmet_version='0.72.20' pymatgen_version='2023...       5
# 40     mp-15549  emmet_version='0.72.20' pymatgen_version='2023...      20
# 67     mp-24199  emmet_version='0.72.20' pymatgen_version='2023...       4
# 166   mp-555591  emmet_version='0.72.20' pymatgen_version='2023...      36
# 174   mp-556996  emmet_version='0.72.20' pymatgen_version='2023...      30
# 402   mp-989504  emmet_version='0.72.20' pymatgen_version='2023...      10
# 497  mp-1113747  emmet_version='0.72.20' pymatgen_version='2023...      10
# ...

# %%
new_df_Li_halide_4V.to_csv('NEW_Shortlist_Li_halides_4V_from_SCREENED_MPJ_18_July_2025.csv', index = False)

# %%
new_df_Li_halide_4V[['material_id', 'formula_pretty', 'theoretical',
                                'catboost_RED_POT_Average_prediction', 'LGBM_RED_POT_Average_prediction', 'xgboost_RED_POT_Average_prediction',
                                'catboost_OXID_POT_Average_prediction', 'LGBM_OXID_POT_Average_prediction', 'xgboost_OXID_POT_Average_prediction',
                               'catboost_ESW', 'LGBM_ESW', 'xgboost_ESW']].describe()
# Out:
#        catboost_RED_POT_Average_prediction  LGBM_RED_POT_Average_prediction  \
# count                            19.000000                        19.000000
# mean                              0.970976                         1.020000
# std                               0.527118                         0.534579
# min                               0.280778                         0.088034
# 25%                               0.759076                         0.845076
# 50%                               0.790923                         1.019624
# 75%                               1.271034                         1.203763
# max                               2.218509                         2.159166
#
#        xgboost_RED_POT_Average_prediction  \
# count                           19.000000
# mean                             0.992937
# std                              0.473441
# min                              0.222260
# 25%                              0.840370
# ...

# %%
new_df_Li_halide_4V[['material_id', 'formula_pretty', 'theoretical',
                                'catboost_RED_POT_Average_prediction', 'LGBM_RED_POT_Average_prediction', 'xgboost_RED_POT_Average_prediction',
                                'catboost_OXID_POT_Average_prediction', 'LGBM_OXID_POT_Average_prediction', 'xgboost_OXID_POT_Average_prediction',
                               'catboost_ESW', 'LGBM_ESW', 'xgboost_ESW']].to_csv('1-NEW_Shortlist_Li_halides_4V_from_SCREENED_MPJ_18_July_2025.csv', index = False)

# %%
new_df_Li_halide_4V['theoretical'].value_counts()
# Out:
# theoretical
# False    13
# True      6
# Name: count, dtype: int64

# %%
new_df_Li[new_df_Li['F'] != 0][['material_id', 'formula_pretty', 'formation_energy_per_atom', 'energy_above_hull', 'band_gap', 'theoretical',
                                'catboost_RED_POT_Average_prediction', 'LGBM_RED_POT_Average_prediction', 'xgboost_RED_POT_Average_prediction',
                                'catboost_OXID_POT_Average_prediction', 'LGBM_OXID_POT_Average_prediction', 'xgboost_OXID_POT_Average_prediction',
                               'catboost_ESW', 'LGBM_ESW', 'xgboost_ESW']]
# Out:
#     material_id formula_pretty  formation_energy_per_atom  energy_above_hull  \
# 8       mp-6134       LiCaAlF6                  -3.871874           0.000000
# 9       mp-6253        KLiBeF4                  -3.354594           0.000000
# 11      mp-6591       SrLiAlF6                  -3.877836           0.000000
# 29      mp-9839       K2LiAlF6                  -3.464196           0.001649
# 32     mp-10250         BaLiF3                  -3.742865           0.021903
# 40     mp-15549       K2LiAlF6                  -3.465729           0.000116
# 67     mp-24199          LiHF2                  -2.539982           0.000000
# 166   mp-555591       SrLiAlF6                  -3.852024           0.025812
# 174   mp-556996       K2LiAlF6                  -3.465845           0.000000
# 402   mp-989504       Na2LiNF6                  -1.812514           0.000000
# 497  mp-1113747      Rb2LiAlF6                  -3.424945           0.000633
# ...

# %%
new_df_Li[new_df_Li['Cl'] != 0][['material_id', 'formula_pretty', 'formation_energy_per_atom', 'energy_above_hull', 'band_gap', 'theoretical',
                                'catboost_RED_POT_Average_prediction', 'LGBM_RED_POT_Average_prediction', 'xgboost_RED_POT_Average_prediction',
                                'catboost_OXID_POT_Average_prediction', 'LGBM_OXID_POT_Average_prediction', 'xgboost_OXID_POT_Average_prediction',
                               'catboost_ESW', 'LGBM_ESW', 'xgboost_ESW']]
# Out:
#     material_id formula_pretty  formation_energy_per_atom  energy_above_hull  \
# 47     mp-22905           LiCl                  -2.025595           0.000000
# 562  mp-1185319           LiCl                  -2.021953           0.003643
#
#      band_gap  theoretical  catboost_RED_POT_Average_prediction  \
# 47     6.2500        False                             0.280778
# 562    5.7373         True                             0.280778
#
#      LGBM_RED_POT_Average_prediction  xgboost_RED_POT_Average_prediction  \
# 47                          0.088034                             0.22226
# 562                         0.088034                             0.22226
#
#      catboost_OXID_POT_Average_prediction  LGBM_OXID_POT_Average_prediction  \
# 47                               4.286254                          4.265301
# 562                              4.286254                          4.265301
#
#      xgboost_OXID_POT_Average_prediction  catboost_ESW  LGBM_ESW  xgboost_ESW
# ...

# %%
new_df_Li[new_df_Li['Br'] != 0][['material_id', 'formula_pretty', 'formation_energy_per_atom', 'energy_above_hull', 'band_gap', 'theoretical',
                                'catboost_RED_POT_Average_prediction', 'LGBM_RED_POT_Average_prediction', 'xgboost_RED_POT_Average_prediction',
                                'catboost_OXID_POT_Average_prediction', 'LGBM_OXID_POT_Average_prediction', 'xgboost_OXID_POT_Average_prediction',
                               'catboost_ESW', 'LGBM_ESW', 'xgboost_ESW']]
# Out:
# Empty DataFrame
# Columns: [material_id, formula_pretty, formation_energy_per_atom, energy_above_hull, band_gap, theoretical, catboost_RED_POT_Average_prediction, LGBM_RED_POT_Average_prediction, xgboost_RED_POT_Average_prediction, catboost_OXID_POT_Average_prediction, LGBM_OXID_POT_Average_prediction, xgboost_OXID_POT_Average_prediction, catboost_ESW, LGBM_ESW, xgboost_ESW]
# Index: []

# %%
new_df_Li[new_df_Li['I'] != 0][['material_id', 'formula_pretty', 'formation_energy_per_atom', 'energy_above_hull', 'band_gap', 'theoretical',
                                'catboost_RED_POT_Average_prediction', 'LGBM_RED_POT_Average_prediction', 'xgboost_RED_POT_Average_prediction',
                                'catboost_OXID_POT_Average_prediction', 'LGBM_OXID_POT_Average_prediction', 'xgboost_OXID_POT_Average_prediction',
                               'catboost_ESW', 'LGBM_ESW', 'xgboost_ESW']]
# Out:
# Empty DataFrame
# Columns: [material_id, formula_pretty, formation_energy_per_atom, energy_above_hull, band_gap, theoretical, catboost_RED_POT_Average_prediction, LGBM_RED_POT_Average_prediction, xgboost_RED_POT_Average_prediction, catboost_OXID_POT_Average_prediction, LGBM_OXID_POT_Average_prediction, xgboost_OXID_POT_Average_prediction, catboost_ESW, LGBM_ESW, xgboost_ESW]
# Index: []

# %%
new_df_Li[['material_id', 'formula_pretty', 'formation_energy_per_atom', 'energy_above_hull', 'band_gap', 'theoretical',
                                'catboost_RED_POT_Average_prediction', 'LGBM_RED_POT_Average_prediction', 'xgboost_RED_POT_Average_prediction',
                                'catboost_OXID_POT_Average_prediction', 'LGBM_OXID_POT_Average_prediction', 'xgboost_OXID_POT_Average_prediction',
                               'catboost_ESW', 'LGBM_ESW', 'xgboost_ESW']]
# Out:
#     material_id formula_pretty  formation_energy_per_atom  energy_above_hull  \
# 8       mp-6134       LiCaAlF6                  -3.871874           0.000000
# 9       mp-6253        KLiBeF4                  -3.354594           0.000000
# 11      mp-6591       SrLiAlF6                  -3.877836           0.000000
# 29      mp-9839       K2LiAlF6                  -3.464196           0.001649
# 32     mp-10250         BaLiF3                  -3.742865           0.021903
# 40     mp-15549       K2LiAlF6                  -3.465729           0.000116
# 47     mp-22905           LiCl                  -2.025595           0.000000
# 67     mp-24199          LiHF2                  -2.539982           0.000000
# 166   mp-555591       SrLiAlF6                  -3.852024           0.025812
# 174   mp-556996       K2LiAlF6                  -3.465845           0.000000
# 402   mp-989504       Na2LiNF6                  -1.812514           0.000000
# ...

# %%
new_df_Li[['material_id', 'formula_pretty', 'formation_energy_per_atom', 'energy_above_hull', 'band_gap', 'theoretical',
                                'catboost_RED_POT_Average_prediction', 'LGBM_RED_POT_Average_prediction', 'xgboost_RED_POT_Average_prediction',
                                'catboost_OXID_POT_Average_prediction', 'LGBM_OXID_POT_Average_prediction', 'xgboost_OXID_POT_Average_prediction',
                               'catboost_ESW', 'LGBM_ESW', 'xgboost_ESW']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19 entries, 8 to 651
# Data columns (total 15 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   material_id                           19 non-null     object
#  1   formula_pretty                        19 non-null     object
#  2   formation_energy_per_atom             19 non-null     float64
#  3   energy_above_hull                     19 non-null     float64
#  4   band_gap                              19 non-null     float64
#  5   theoretical                           19 non-null     bool
#  6   catboost_RED_POT_Average_prediction   19 non-null     float64
#  7   LGBM_RED_POT_Average_prediction       19 non-null     float64
#  8   xgboost_RED_POT_Average_prediction    19 non-null     float64
#  9   catboost_OXID_POT_Average_prediction  19 non-null     float64
#  10  LGBM_OXID_POT_Average_prediction      19 non-null     float64
# ...

# %%
new_df_Li_halide_4V[['material_id', 'formula_pretty', 'formation_energy_per_atom', 'energy_above_hull', 'band_gap', 'theoretical',
                                'catboost_RED_POT_Average_prediction', 'LGBM_RED_POT_Average_prediction', 'xgboost_RED_POT_Average_prediction',
                                'catboost_OXID_POT_Average_prediction', 'LGBM_OXID_POT_Average_prediction', 'xgboost_OXID_POT_Average_prediction',
                               'catboost_ESW', 'LGBM_ESW', 'xgboost_ESW']].describe().to_csv('NEW_Statistics_of_ESW_predictions_by_best_ML_models_for_SCREENED_Li_halides_4V_from_MPJ_dataset_18_July_2025.csv')

# %%
new_df_Li_halide_4V[['material_id', 'formula_pretty', 'formation_energy_per_atom', 'energy_above_hull', 'band_gap', 'theoretical',
                                'catboost_RED_POT_Average_prediction', 'LGBM_RED_POT_Average_prediction', 'xgboost_RED_POT_Average_prediction',
                                'catboost_OXID_POT_Average_prediction', 'LGBM_OXID_POT_Average_prediction', 'xgboost_OXID_POT_Average_prediction',
                               'catboost_ESW', 'LGBM_ESW', 'xgboost_ESW']].describe()
# Out:
#        formation_energy_per_atom  energy_above_hull   band_gap  \
# count                  19.000000          19.000000  19.000000
# mean                   -3.183129           0.007067   6.933000
# std                     0.678225           0.011253   1.292836
# min                    -3.877836           0.000000   2.476700
# 25%                    -3.729549           0.000000   6.713050
# 50%                    -3.424945           0.000633   7.263900
# 75%                    -2.778402           0.011361   7.568200
# max                    -1.812514           0.034970   8.596500
#
#        catboost_RED_POT_Average_prediction  LGBM_RED_POT_Average_prediction  \
# count                            19.000000                        19.000000
# mean                              0.970976                         1.020000
# std                               0.527118                         0.534579
# min                               0.280778                         0.088034
# ...

# %%
new_df_Li
# Out:
#     material_id                                       builder_meta  nsites  \
# 8       mp-6134  emmet_version='0.72.20' pymatgen_version='2023...      18
# 9       mp-6253  emmet_version='0.72.20' pymatgen_version='2023...      14
# 11      mp-6591  emmet_version='0.72.20' pymatgen_version='2023...      18
# 29      mp-9839  emmet_version='0.72.20' pymatgen_version='2023...      10
# 32     mp-10250  emmet_version='0.72.20' pymatgen_version='2023...       5
# 40     mp-15549  emmet_version='0.72.20' pymatgen_version='2023...      20
# 47     mp-22905  emmet_version='0.72.20' pymatgen_version='2023...       2
# 67     mp-24199  emmet_version='0.72.20' pymatgen_version='2023...       4
# 166   mp-555591  emmet_version='0.72.20' pymatgen_version='2023...      36
# 174   mp-556996  emmet_version='0.72.20' pymatgen_version='2023...      30
# 402   mp-989504  emmet_version='0.72.20' pymatgen_version='2023...      10
# ...

# %%
new_df_Li.to_csv('NEW_Shortlist_Li_compounds_4V_from_SCREENED_MPJ_18_July_2025.csv', index = False)

# %%
new_df_Li[['material_id', 'formula_pretty', 'formation_energy_per_atom', 'energy_above_hull', 'band_gap', 'theoretical',
                                'catboost_RED_POT_Average_prediction', 'LGBM_RED_POT_Average_prediction', 'xgboost_RED_POT_Average_prediction',
                                'catboost_OXID_POT_Average_prediction', 'LGBM_OXID_POT_Average_prediction', 'xgboost_OXID_POT_Average_prediction',
                               'catboost_ESW', 'LGBM_ESW', 'xgboost_ESW']].to_csv('1-NEW_Shortlist_Li_compounds_4V_from_SCREENED_MPJ_18_July_2025.csv', index = False)
