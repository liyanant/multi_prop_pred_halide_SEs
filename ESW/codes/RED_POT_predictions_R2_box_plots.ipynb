# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
RED_POT_trad_train_df = pd.read_csv('Trad_ML/Reduction_potential/RED_POT_TRAIN_R2.csv')
RED_POT_trad_train_df
# Out:
#     catboost      LGBM   xgboost
# 0   0.979625  0.978279  0.973510
# 1   0.980234  0.977638  0.973963
# 2   0.979991  0.977241  0.972883
# 3   0.981331  0.978515  0.971599
# 4   0.978530  0.978413  0.972340
# ..       ...       ...       ...
# 95  0.980250  0.977297  0.970900
# 96  0.977701  0.977193  0.970296
# 97  0.980057  0.977857  0.971361
# 98  0.980608  0.979487  0.973183
# 99  0.980959  0.978536  0.972221
#
# [100 rows x 3 columns]

# %%
RED_POT_trad_train_df.describe()
# Out:
#          catboost        LGBM     xgboost
# count  100.000000  100.000000  100.000000
# mean     0.980090    0.977997    0.972425
# std      0.001181    0.001250    0.001657
# min      0.977289    0.974388    0.968865
# 25%      0.979337    0.977139    0.971375
# 50%      0.979931    0.977875    0.972389
# 75%      0.980779    0.978716    0.973471
# max      0.983741    0.981957    0.976989

# %%
RED_POT_trad_train_df = RED_POT_trad_train_df[['catboost', 'LGBM', 'xgboost']]
RED_POT_trad_train_df
# Out:
#     catboost      LGBM   xgboost
# 0   0.979625  0.978279  0.973510
# 1   0.980234  0.977638  0.973963
# 2   0.979991  0.977241  0.972883
# 3   0.981331  0.978515  0.971599
# 4   0.978530  0.978413  0.972340
# ..       ...       ...       ...
# 95  0.980250  0.977297  0.970900
# 96  0.977701  0.977193  0.970296
# 97  0.980057  0.977857  0.971361
# 98  0.980608  0.979487  0.973183
# 99  0.980959  0.978536  0.972221
#
# [100 rows x 3 columns]

# %%
RED_POT_skorch_train_df = pd.read_csv('Skorch_NN/Reduction_potential/RED_POT_TRAIN_R2.csv')
RED_POT_skorch_train_df
# Out:
#     skorch_model_1  skorch_model_2  skorch_model_3
# 0         0.928129        0.929828        0.929629
# 1         0.931454        0.928907        0.929842
# 2         0.929223        0.929470        0.933586
# 3         0.932945        0.929180        0.931632
# 4         0.928460        0.926215        0.930029
# ..             ...             ...             ...
# 95        0.925564        0.920613        0.922723
# 96        0.923191        0.922920        0.928998
# 97        0.923450        0.923180        0.925501
# 98        0.927173        0.930071        0.928451
# 99        0.931380        0.930942        0.930827
#
# [100 rows x 3 columns]

# %%
RED_POT_skorch_train_df.describe()
# Out:
#        skorch_model_1  skorch_model_2  skorch_model_3
# count      100.000000      100.000000      100.000000
# mean         0.927743        0.927640        0.927744
# std          0.004390        0.003962        0.004204
# min          0.914678        0.918033        0.913944
# 25%          0.924738        0.924850        0.924555
# 50%          0.928113        0.928129        0.928220
# 75%          0.931059        0.930105        0.931068
# max          0.939988        0.937016        0.935949

# %%
RED_POT_skorch_train_df.columns = ['skorch_1', 'skorch_2', 'skorch_3']
RED_POT_skorch_train_df
# Out:
#     skorch_1  skorch_2  skorch_3
# 0   0.928129  0.929828  0.929629
# 1   0.931454  0.928907  0.929842
# 2   0.929223  0.929470  0.933586
# 3   0.932945  0.929180  0.931632
# 4   0.928460  0.926215  0.930029
# ..       ...       ...       ...
# 95  0.925564  0.920613  0.922723
# 96  0.923191  0.922920  0.928998
# 97  0.923450  0.923180  0.925501
# 98  0.927173  0.930071  0.928451
# 99  0.931380  0.930942  0.930827
#
# [100 rows x 3 columns]

# %%
RED_POT_train_df = pd.concat([RED_POT_trad_train_df, RED_POT_skorch_train_df], axis = 1)
RED_POT_train_df
# Out:
#     catboost      LGBM   xgboost  skorch_1  skorch_2  skorch_3
# 0   0.979625  0.978279  0.973510  0.928129  0.929828  0.929629
# 1   0.980234  0.977638  0.973963  0.931454  0.928907  0.929842
# 2   0.979991  0.977241  0.972883  0.929223  0.929470  0.933586
# 3   0.981331  0.978515  0.971599  0.932945  0.929180  0.931632
# 4   0.978530  0.978413  0.972340  0.928460  0.926215  0.930029
# ..       ...       ...       ...       ...       ...       ...
# 95  0.980250  0.977297  0.970900  0.925564  0.920613  0.922723
# 96  0.977701  0.977193  0.970296  0.923191  0.922920  0.928998
# 97  0.980057  0.977857  0.971361  0.923450  0.923180  0.925501
# 98  0.980608  0.979487  0.973183  0.927173  0.930071  0.928451
# 99  0.980959  0.978536  0.972221  0.931380  0.930942  0.930827
#
# [100 rows x 6 columns]

# %%
RED_POT_trad_test_df = pd.read_csv('Trad_ML/Reduction_potential/RED_POT_HOLDOUT_R2.csv')
RED_POT_trad_test_df
# Out:
#     catboost      LGBM   xgboost
# 0   0.867331  0.857682  0.850542
# 1   0.854625  0.834223  0.839575
# 2   0.886863  0.880600  0.872215
# 3   0.875596  0.858105  0.862260
# 4   0.860541  0.856097  0.842725
# ..       ...       ...       ...
# 95  0.891380  0.884983  0.871019
# 96  0.902853  0.893802  0.900624
# 97  0.874899  0.869351  0.861707
# 98  0.842999  0.835190  0.832274
# 99  0.892009  0.876683  0.877415
#
# [100 rows x 3 columns]

# %%
RED_POT_trad_test_df.describe()
# Out:
#          catboost        LGBM     xgboost
# count  100.000000  100.000000  100.000000
# mean     0.873692    0.863891    0.861946
# std      0.016059    0.016033    0.016013
# min      0.837489    0.824507    0.825672
# 25%      0.863322    0.854638    0.851098
# 50%      0.874269    0.864319    0.862799
# 75%      0.885795    0.872955    0.871668
# max      0.910317    0.911664    0.909837

# %%
RED_POT_trad_test_df = RED_POT_trad_test_df[['catboost', 'LGBM', 'xgboost']]
RED_POT_trad_test_df
# Out:
#     catboost      LGBM   xgboost
# 0   0.867331  0.857682  0.850542
# 1   0.854625  0.834223  0.839575
# 2   0.886863  0.880600  0.872215
# 3   0.875596  0.858105  0.862260
# 4   0.860541  0.856097  0.842725
# ..       ...       ...       ...
# 95  0.891380  0.884983  0.871019
# 96  0.902853  0.893802  0.900624
# 97  0.874899  0.869351  0.861707
# 98  0.842999  0.835190  0.832274
# 99  0.892009  0.876683  0.877415
#
# [100 rows x 3 columns]

# %%
RED_POT_skorch_test_df = pd.read_csv('Skorch_NN/Reduction_potential/RED_POT_HOLDOUT_R2.csv')
RED_POT_skorch_test_df
# Out:
#     skorch_model_1  skorch_model_2  skorch_model_3
# 0         0.856484        0.853359        0.858114
# 1         0.850796        0.853428        0.852386
# 2         0.862787        0.866633        0.870354
# 3         0.865131        0.863908        0.864291
# 4         0.851611        0.851759        0.856190
# ..             ...             ...             ...
# 95        0.857400        0.859369        0.859352
# 96        0.870633        0.871359        0.880826
# 97        0.869769        0.863452        0.866916
# 98        0.809517        0.810595        0.807547
# 99        0.883766        0.890874        0.881256
#
# [100 rows x 3 columns]

# %%
RED_POT_skorch_test_df.describe()
# Out:
#        skorch_model_1  skorch_model_2  skorch_model_3
# count      100.000000      100.000000      100.000000
# mean         0.852496        0.853173        0.852063
# std          0.019907        0.020294        0.021044
# min          0.796717        0.786929        0.782725
# 25%          0.842301        0.844818        0.841440
# 50%          0.854134        0.853849        0.855193
# 75%          0.865192        0.865373        0.864796
# max          0.892643        0.897139        0.893796

# %%
RED_POT_skorch_test_df.columns = ['skorch_1', 'skorch_2', 'skorch_3']
RED_POT_skorch_test_df
# Out:
#     skorch_1  skorch_2  skorch_3
# 0   0.856484  0.853359  0.858114
# 1   0.850796  0.853428  0.852386
# 2   0.862787  0.866633  0.870354
# 3   0.865131  0.863908  0.864291
# 4   0.851611  0.851759  0.856190
# ..       ...       ...       ...
# 95  0.857400  0.859369  0.859352
# 96  0.870633  0.871359  0.880826
# 97  0.869769  0.863452  0.866916
# 98  0.809517  0.810595  0.807547
# 99  0.883766  0.890874  0.881256
#
# [100 rows x 3 columns]

# %%
RED_POT_test_df = pd.concat([RED_POT_trad_test_df, RED_POT_skorch_test_df], axis = 1)
RED_POT_test_df
# Out:
#     catboost      LGBM   xgboost  skorch_1  skorch_2  skorch_3
# 0   0.867331  0.857682  0.850542  0.856484  0.853359  0.858114
# 1   0.854625  0.834223  0.839575  0.850796  0.853428  0.852386
# 2   0.886863  0.880600  0.872215  0.862787  0.866633  0.870354
# 3   0.875596  0.858105  0.862260  0.865131  0.863908  0.864291
# 4   0.860541  0.856097  0.842725  0.851611  0.851759  0.856190
# ..       ...       ...       ...       ...       ...       ...
# 95  0.891380  0.884983  0.871019  0.857400  0.859369  0.859352
# 96  0.902853  0.893802  0.900624  0.870633  0.871359  0.880826
# 97  0.874899  0.869351  0.861707  0.869769  0.863452  0.866916
# 98  0.842999  0.835190  0.832274  0.809517  0.810595  0.807547
# 99  0.892009  0.876683  0.877415  0.883766  0.890874  0.881256
#
# [100 rows x 6 columns]

# %%
labels = RED_POT_test_df.columns

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(30, 10))

plt.rcParams.update({'font.size': 22, 'font.weight':'bold'})
bplot1 = ax1.boxplot(RED_POT_train_df,
                     vert=True,
                     patch_artist=True,
                     labels=labels)
ax1.set_title('Training Rectangular box plot', fontsize = 24, fontweight='bold')


bplot2 = ax2.boxplot(RED_POT_test_df,
                     vert=True,
                     patch_artist=True,
                     labels=labels)
ax2.set_title('Holdout Rectangular box plot', fontsize = 24, fontweight='bold')

colors = ['red', 'blue', 'orange', 'violet', 'yellow', 'green', 'pink', 'brown', 'lightblue', 'magenta', 'lightgreen', 'cyan', 'beige']
for bplot in (bplot1, bplot2):
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)

for ax in [ax1, ax2]:
    ax.yaxis.grid(False)
    ax.xaxis.grid(False)
    ax.set_ylabel('$\mathregular{R^2}$', fontsize = 24, fontweight='bold')

plt.show()
