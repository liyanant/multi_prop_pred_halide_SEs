# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
OXID_POT_trad_train_df = pd.read_csv('Trad_ML/Oxidation_potential/OXID_POT_TRAIN_R2.csv')
OXID_POT_trad_train_df
# Out:
#     catboost      LGBM   xgboost
# 0   0.965518  0.915278  0.944311
# 1   0.968378  0.920044  0.946590
# 2   0.964515  0.915725  0.945204
# 3   0.965322  0.919241  0.945867
# 4   0.962583  0.916438  0.940741
# ..       ...       ...       ...
# 95  0.966451  0.919944  0.946587
# 96  0.964027  0.917274  0.944635
# 97  0.959572  0.917131  0.941504
# 98  0.964283  0.915321  0.943887
# 99  0.962421  0.915615  0.943536
#
# [100 rows x 3 columns]

# %%
OXID_POT_trad_train_df.describe()
# Out:
#          catboost        LGBM     xgboost
# count  100.000000  100.000000  100.000000
# mean     0.964952    0.917552    0.945000
# std      0.002013    0.002087    0.002067
# min      0.959181    0.912831    0.939680
# 25%      0.963551    0.916087    0.943901
# 50%      0.965065    0.917366    0.945174
# 75%      0.966362    0.919127    0.946334
# max      0.969212    0.923914    0.949825

# %%
OXID_POT_trad_train_df = OXID_POT_trad_train_df[['catboost', 'LGBM', 'xgboost']]
OXID_POT_trad_train_df
# Out:
#     catboost      LGBM   xgboost
# 0   0.965518  0.915278  0.944311
# 1   0.968378  0.920044  0.946590
# 2   0.964515  0.915725  0.945204
# 3   0.965322  0.919241  0.945867
# 4   0.962583  0.916438  0.940741
# ..       ...       ...       ...
# 95  0.966451  0.919944  0.946587
# 96  0.964027  0.917274  0.944635
# 97  0.959572  0.917131  0.941504
# 98  0.964283  0.915321  0.943887
# 99  0.962421  0.915615  0.943536
#
# [100 rows x 3 columns]

# %%
OXID_POT_skorch_train_df = pd.read_csv('Skorch_NN/Oxidation_potential/OXID_POT_TRAIN_R2.csv')
OXID_POT_skorch_train_df
# Out:
#     skorch_model_1  skorch_model_2  skorch_model_3
# 0         0.925893        0.929026        0.924733
# 1         0.920139        0.929969        0.925151
# 2         0.922287        0.922845        0.926276
# 3         0.931184        0.922446        0.924215
# 4         0.922036        0.917166        0.925016
# ..             ...             ...             ...
# 95        0.919211        0.916729        0.923351
# 96        0.926449        0.926738        0.922944
# 97        0.914524        0.919317        0.922648
# 98        0.925838        0.918606        0.918003
# 99        0.914774        0.916550        0.902832
#
# [100 rows x 3 columns]

# %%
OXID_POT_skorch_train_df.describe()
# Out:
#        skorch_model_1  skorch_model_2  skorch_model_3
# count      100.000000      100.000000      100.000000
# mean         0.921751        0.921556        0.921688
# std          0.004998        0.005020        0.005665
# min          0.901038        0.906210        0.902550
# 25%          0.918453        0.918061        0.919308
# 50%          0.922006        0.922103        0.922466
# 75%          0.925041        0.924978        0.925067
# max          0.931972        0.931191        0.934322

# %%
OXID_POT_skorch_train_df.columns = ['skorch_1', 'skorch_2', 'skorch_3']
OXID_POT_skorch_train_df
# Out:
#     skorch_1  skorch_2  skorch_3
# 0   0.925893  0.929026  0.924733
# 1   0.920139  0.929969  0.925151
# 2   0.922287  0.922845  0.926276
# 3   0.931184  0.922446  0.924215
# 4   0.922036  0.917166  0.925016
# ..       ...       ...       ...
# 95  0.919211  0.916729  0.923351
# 96  0.926449  0.926738  0.922944
# 97  0.914524  0.919317  0.922648
# 98  0.925838  0.918606  0.918003
# 99  0.914774  0.916550  0.902832
#
# [100 rows x 3 columns]

# %%
OXID_POT_train_df = pd.concat([OXID_POT_trad_train_df, OXID_POT_skorch_train_df], axis = 1)
OXID_POT_train_df
# Out:
#     catboost      LGBM   xgboost  skorch_1  skorch_2  skorch_3
# 0   0.965518  0.915278  0.944311  0.925893  0.929026  0.924733
# 1   0.968378  0.920044  0.946590  0.920139  0.929969  0.925151
# 2   0.964515  0.915725  0.945204  0.922287  0.922845  0.926276
# 3   0.965322  0.919241  0.945867  0.931184  0.922446  0.924215
# 4   0.962583  0.916438  0.940741  0.922036  0.917166  0.925016
# ..       ...       ...       ...       ...       ...       ...
# 95  0.966451  0.919944  0.946587  0.919211  0.916729  0.923351
# 96  0.964027  0.917274  0.944635  0.926449  0.926738  0.922944
# 97  0.959572  0.917131  0.941504  0.914524  0.919317  0.922648
# 98  0.964283  0.915321  0.943887  0.925838  0.918606  0.918003
# 99  0.962421  0.915615  0.943536  0.914774  0.916550  0.902832
#
# [100 rows x 6 columns]

# %%
OXID_POT_trad_test_df = pd.read_csv('Trad_ML/Oxidation_potential/OXID_POT_HOLDOUT_R2.csv')
OXID_POT_trad_test_df
# Out:
#     catboost      LGBM   xgboost
# 0   0.801417  0.796251  0.806708
# 1   0.719795  0.726835  0.723503
# 2   0.794281  0.794351  0.795230
# 3   0.767402  0.770837  0.770558
# 4   0.773111  0.771596  0.777364
# ..       ...       ...       ...
# 95  0.779887  0.776060  0.791972
# 96  0.785830  0.780726  0.784377
# 97  0.815002  0.791323  0.811862
# 98  0.779183  0.781647  0.777659
# 99  0.811427  0.804013  0.803320
#
# [100 rows x 3 columns]

# %%
OXID_POT_trad_test_df.describe()
# Out:
#          catboost        LGBM     xgboost
# count  100.000000  100.000000  100.000000
# mean     0.778272    0.771203    0.780205
# std      0.023952    0.023583    0.023528
# min      0.705772    0.709641    0.713836
# 25%      0.765140    0.757876    0.766966
# 50%      0.779356    0.771875    0.779973
# 75%      0.793857    0.787198    0.795676
# max      0.833323    0.814911    0.836998

# %%
OXID_POT_trad_test_df = OXID_POT_trad_test_df[['catboost', 'LGBM', 'xgboost']]
OXID_POT_trad_test_df
# Out:
#     catboost      LGBM   xgboost
# 0   0.801417  0.796251  0.806708
# 1   0.719795  0.726835  0.723503
# 2   0.794281  0.794351  0.795230
# 3   0.767402  0.770837  0.770558
# 4   0.773111  0.771596  0.777364
# ..       ...       ...       ...
# 95  0.779887  0.776060  0.791972
# 96  0.785830  0.780726  0.784377
# 97  0.815002  0.791323  0.811862
# 98  0.779183  0.781647  0.777659
# 99  0.811427  0.804013  0.803320
#
# [100 rows x 3 columns]

# %%
OXID_POT_skorch_test_df = pd.read_csv('Skorch_NN/Oxidation_potential/OXID_POT_HOLDOUT_R2.csv')
OXID_POT_skorch_test_df
# Out:
#     skorch_model_1  skorch_model_2  skorch_model_3
# 0         0.803476        0.798597        0.790912
# 1         0.725284        0.729665        0.740079
# 2         0.756751        0.774735        0.761374
# 3         0.766997        0.772761        0.769585
# 4         0.766627        0.752234        0.766118
# ..             ...             ...             ...
# 95        0.778220        0.774063        0.768783
# 96        0.781508        0.771794        0.775321
# 97        0.794430        0.797196        0.803367
# 98        0.777618        0.784065        0.779584
# 99        0.814384        0.812381        0.798897
#
# [100 rows x 3 columns]

# %%
OXID_POT_skorch_test_df.describe()
# Out:
#        skorch_model_1  skorch_model_2  skorch_model_3
# count      100.000000      100.000000      100.000000
# mean         0.771740        0.771279        0.772385
# std          0.024607        0.024632        0.024143
# min          0.704367        0.706780        0.702866
# 25%          0.761071        0.757233        0.761621
# 50%          0.771709        0.771944        0.772589
# 75%          0.785928        0.787040        0.789711
# max          0.819095        0.820861        0.821603

# %%
OXID_POT_skorch_test_df.columns = ['skorch_1', 'skorch_2', 'skorch_3']
OXID_POT_skorch_test_df
# Out:
#     skorch_1  skorch_2  skorch_3
# 0   0.803476  0.798597  0.790912
# 1   0.725284  0.729665  0.740079
# 2   0.756751  0.774735  0.761374
# 3   0.766997  0.772761  0.769585
# 4   0.766627  0.752234  0.766118
# ..       ...       ...       ...
# 95  0.778220  0.774063  0.768783
# 96  0.781508  0.771794  0.775321
# 97  0.794430  0.797196  0.803367
# 98  0.777618  0.784065  0.779584
# 99  0.814384  0.812381  0.798897
#
# [100 rows x 3 columns]

# %%
OXID_POT_test_df = pd.concat([OXID_POT_trad_test_df, OXID_POT_skorch_test_df], axis = 1)
OXID_POT_test_df
# Out:
#     catboost      LGBM   xgboost  skorch_1  skorch_2  skorch_3
# 0   0.801417  0.796251  0.806708  0.803476  0.798597  0.790912
# 1   0.719795  0.726835  0.723503  0.725284  0.729665  0.740079
# 2   0.794281  0.794351  0.795230  0.756751  0.774735  0.761374
# 3   0.767402  0.770837  0.770558  0.766997  0.772761  0.769585
# 4   0.773111  0.771596  0.777364  0.766627  0.752234  0.766118
# ..       ...       ...       ...       ...       ...       ...
# 95  0.779887  0.776060  0.791972  0.778220  0.774063  0.768783
# 96  0.785830  0.780726  0.784377  0.781508  0.771794  0.775321
# 97  0.815002  0.791323  0.811862  0.794430  0.797196  0.803367
# 98  0.779183  0.781647  0.777659  0.777618  0.784065  0.779584
# 99  0.811427  0.804013  0.803320  0.814384  0.812381  0.798897
#
# [100 rows x 6 columns]

# %%
labels = OXID_POT_test_df.columns

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(30, 10))

plt.rcParams.update({'font.size': 22, 'font.weight':'bold'})
bplot1 = ax1.boxplot(OXID_POT_train_df,
                     vert=True,
                     patch_artist=True,
                     labels=labels)
ax1.set_title('Training Rectangular box plot', fontsize = 24, fontweight='bold')


bplot2 = ax2.boxplot(OXID_POT_test_df,
                     vert=True,
                     patch_artist=True,
                     labels=labels)
ax2.set_title('Holdout Rectangular box plot', fontsize = 24, fontweight='bold')


# fill with colors
colors = ['red', 'blue', 'orange', 'violet', 'yellow', 'green', 'pink', 'brown', 'lightblue', 'magenta', 'lightgreen', 'cyan', 'beige']
for bplot in (bplot1, bplot2):
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)

for ax in [ax1, ax2]:
    ax.yaxis.grid(False)
    ax.xaxis.grid(False)
    ax.set_ylabel('$\mathregular{R^2}$', fontsize = 24, fontweight='bold')

plt.show()
