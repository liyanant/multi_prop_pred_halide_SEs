# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pwd
# Out:
# /content

# %%
df = pd.read_csv('ESW_prediction_dataset.csv')
df
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 3        mp-3887  emmet_version='0.72.20' pymatgen_version='2023...      48
# 4        mp-3949  emmet_version='0.72.20' pymatgen_version='2023...      64
# ...          ...                                                ...     ...
# 5319  mp-2712854  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5320  mp-2712928  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5321  mp-2713730  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5322  mp-2713752  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5323  mp-2713949  emmet_version='0.72.20' pymatgen_version='2023...     102
#
# ...

# %%
df1 = pd.read_csv('NEW_Average_skorch_NN_model_predictions_for_RED_POT_18_July_2025.csv')
df1
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 3        mp-3887  emmet_version='0.72.20' pymatgen_version='2023...      48
# 4        mp-3949  emmet_version='0.72.20' pymatgen_version='2023...      64
# ...          ...                                                ...     ...
# 5319  mp-2712854  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5320  mp-2712928  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5321  mp-2713730  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5322  mp-2713752  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5323  mp-2713949  emmet_version='0.72.20' pymatgen_version='2023...     102
#
# ...

# %%
df2 = pd.read_csv('NEW_Average_skorch_NN_model_predictions_for_OXID_POT_18_July_2025.csv')
df2
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 3        mp-3887  emmet_version='0.72.20' pymatgen_version='2023...      48
# 4        mp-3949  emmet_version='0.72.20' pymatgen_version='2023...      64
# ...          ...                                                ...     ...
# 5319  mp-2712854  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5320  mp-2712928  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5321  mp-2713730  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5322  mp-2713752  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5323  mp-2713949  emmet_version='0.72.20' pymatgen_version='2023...     102
#
# ...

# %%
new_df = pd.concat([df, df1[['skorch_model_1_Average_prediction', 'skorch_model_2_Average_prediction', 'skorch_model_3_Average_prediction']]], axis = 1)
new_df
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 3        mp-3887  emmet_version='0.72.20' pymatgen_version='2023...      48
# 4        mp-3949  emmet_version='0.72.20' pymatgen_version='2023...      64
# ...          ...                                                ...     ...
# 5319  mp-2712854  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5320  mp-2712928  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5321  mp-2713730  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5322  mp-2713752  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5323  mp-2713949  emmet_version='0.72.20' pymatgen_version='2023...     102
#
# ...

# %%
new_df[['skorch_model_1_RED_POT_Average_prediction', 'skorch_model_2_RED_POT_Average_prediction', 'skorch_model_3_RED_POT_Average_prediction']] = new_df[['skorch_model_1_Average_prediction', 'skorch_model_2_Average_prediction', 'skorch_model_3_Average_prediction']]
new_df
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 3        mp-3887  emmet_version='0.72.20' pymatgen_version='2023...      48
# 4        mp-3949  emmet_version='0.72.20' pymatgen_version='2023...      64
# ...          ...                                                ...     ...
# 5319  mp-2712854  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5320  mp-2712928  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5321  mp-2713730  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5322  mp-2713752  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5323  mp-2713949  emmet_version='0.72.20' pymatgen_version='2023...     102
#
# ...

# %%
new_df = new_df.drop(['skorch_model_1_Average_prediction', 'skorch_model_2_Average_prediction', 'skorch_model_3_Average_prediction'], axis = 1)
new_df
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 3        mp-3887  emmet_version='0.72.20' pymatgen_version='2023...      48
# 4        mp-3949  emmet_version='0.72.20' pymatgen_version='2023...      64
# ...          ...                                                ...     ...
# 5319  mp-2712854  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5320  mp-2712928  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5321  mp-2713730  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5322  mp-2713752  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5323  mp-2713949  emmet_version='0.72.20' pymatgen_version='2023...     102
#
# ...

# %%
new_df = pd.concat([new_df, df2[['skorch_model_1_Average_prediction', 'skorch_model_2_Average_prediction', 'skorch_model_3_Average_prediction']]], axis = 1)
new_df
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 3        mp-3887  emmet_version='0.72.20' pymatgen_version='2023...      48
# 4        mp-3949  emmet_version='0.72.20' pymatgen_version='2023...      64
# ...          ...                                                ...     ...
# 5319  mp-2712854  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5320  mp-2712928  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5321  mp-2713730  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5322  mp-2713752  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5323  mp-2713949  emmet_version='0.72.20' pymatgen_version='2023...     102
#
# ...

# %%
new_df[['skorch_model_1_OXID_POT_Average_prediction', 'skorch_model_2_OXID_POT_Average_prediction', 'skorch_model_3_OXID_POT_Average_prediction']] = new_df[['skorch_model_1_Average_prediction', 'skorch_model_2_Average_prediction', 'skorch_model_3_Average_prediction']]
new_df
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 3        mp-3887  emmet_version='0.72.20' pymatgen_version='2023...      48
# 4        mp-3949  emmet_version='0.72.20' pymatgen_version='2023...      64
# ...          ...                                                ...     ...
# 5319  mp-2712854  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5320  mp-2712928  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5321  mp-2713730  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5322  mp-2713752  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5323  mp-2713949  emmet_version='0.72.20' pymatgen_version='2023...     102
#
# ...

# %%
new_df = new_df.drop(['skorch_model_1_Average_prediction', 'skorch_model_2_Average_prediction', 'skorch_model_3_Average_prediction'], axis = 1)
new_df
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 3        mp-3887  emmet_version='0.72.20' pymatgen_version='2023...      48
# 4        mp-3949  emmet_version='0.72.20' pymatgen_version='2023...      64
# ...          ...                                                ...     ...
# 5319  mp-2712854  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5320  mp-2712928  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5321  mp-2713730  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5322  mp-2713752  emmet_version='0.72.20' pymatgen_version='2023...     102
# 5323  mp-2713949  emmet_version='0.72.20' pymatgen_version='2023...     102
#
# ...

# %%
new_df[['skorch_model_1_RED_POT_Average_prediction', 'skorch_model_2_RED_POT_Average_prediction', 'skorch_model_3_RED_POT_Average_prediction']].describe()
# Out:
#        skorch_model_1_RED_POT_Average_prediction  \
# count                                5324.000000
# mean                                    1.512585
# std                                     0.875224
# min                                    -0.191952
# 25%                                     0.810767
# 50%                                     1.487441
# 75%                                     2.150676
# max                                     5.373848
#
#        skorch_model_2_RED_POT_Average_prediction  \
# count                                5324.000000
# mean                                    1.512613
# std                                     0.873731
# min                                    -0.175321
# 25%                                     0.813646
# 50%                                     1.483507
# 75%                                     2.145642
# max                                     5.380614
#
#        skorch_model_3_RED_POT_Average_prediction
# ...

# %%
new_df[['skorch_model_1_OXID_POT_Average_prediction', 'skorch_model_2_OXID_POT_Average_prediction', 'skorch_model_3_OXID_POT_Average_prediction']].describe()
# Out:
#        skorch_model_1_OXID_POT_Average_prediction  \
# count                                 5324.000000
# mean                                     3.873749
# std                                      1.224016
# min                                      0.291834
# 25%                                      3.006263
# 50%                                      3.984607
# 75%                                      4.653637
# max                                      9.722728
#
#        skorch_model_2_OXID_POT_Average_prediction  \
# count                                 5324.000000
# mean                                     3.879091
# std                                      1.219904
# min                                      0.311093
# 25%                                      3.011801
# 50%                                      3.994190
# 75%                                      4.655188
# max                                      9.774531
#
#        skorch_model_3_OXID_POT_Average_prediction
# ...

# %%
new_df = new_df[new_df['skorch_model_1_OXID_POT_Average_prediction'] >= 4.0]
new_df = new_df[new_df['skorch_model_2_OXID_POT_Average_prediction'] >= 4.0]
new_df = new_df[new_df['skorch_model_3_OXID_POT_Average_prediction'] >= 4.0]

# %%
new_df
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 6        mp-4855  emmet_version='0.72.20' pymatgen_version='2023...      42
# 7        mp-6075  emmet_version='0.72.20' pymatgen_version='2023...      36
# ...          ...                                                ...     ...
# 5299  mp-1229104  emmet_version='0.72.20' pymatgen_version='2023...      56
# 5301  mp-1229117  emmet_version='0.72.20' pymatgen_version='2023...      64
# 5310  mp-1247815  emmet_version='0.72.20' pymatgen_version='2023...      64
# 5314  mp-1247898  emmet_version='0.72.20' pymatgen_version='2023...      98
# 5317  mp-1267554  emmet_version='0.72.20' pymatgen_version='2023...      98
#
# ...

# %%
new_df[['skorch_model_1_RED_POT_Average_prediction', 'skorch_model_2_RED_POT_Average_prediction', 'skorch_model_3_RED_POT_Average_prediction', 'skorch_model_1_OXID_POT_Average_prediction', 'skorch_model_2_OXID_POT_Average_prediction', 'skorch_model_3_OXID_POT_Average_prediction']].describe()
# Out:
#        skorch_model_1_RED_POT_Average_prediction  \
# count                                2610.000000
# mean                                    2.032020
# std                                     0.782709
# min                                    -0.021221
# 25%                                     1.522537
# 50%                                     2.067417
# 75%                                     2.588011
# max                                     5.373848
#
#        skorch_model_2_RED_POT_Average_prediction  \
# count                                2610.000000
# mean                                    2.031295
# std                                     0.781111
# min                                    -0.010258
# 25%                                     1.520015
# 50%                                     2.061310
# 75%                                     2.594825
# max                                     5.380614
#
#        skorch_model_3_RED_POT_Average_prediction  \
# ...

# %%
new_df['skorch_model_1_ESW'] = new_df['skorch_model_1_OXID_POT_Average_prediction'] - new_df['skorch_model_1_RED_POT_Average_prediction']
new_df
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 6        mp-4855  emmet_version='0.72.20' pymatgen_version='2023...      42
# 7        mp-6075  emmet_version='0.72.20' pymatgen_version='2023...      36
# ...          ...                                                ...     ...
# 5299  mp-1229104  emmet_version='0.72.20' pymatgen_version='2023...      56
# 5301  mp-1229117  emmet_version='0.72.20' pymatgen_version='2023...      64
# 5310  mp-1247815  emmet_version='0.72.20' pymatgen_version='2023...      64
# 5314  mp-1247898  emmet_version='0.72.20' pymatgen_version='2023...      98
# 5317  mp-1267554  emmet_version='0.72.20' pymatgen_version='2023...      98
#
# ...

# %%
new_df['skorch_model_2_ESW'] = new_df['skorch_model_2_OXID_POT_Average_prediction'] - new_df['skorch_model_2_RED_POT_Average_prediction']
new_df
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 6        mp-4855  emmet_version='0.72.20' pymatgen_version='2023...      42
# 7        mp-6075  emmet_version='0.72.20' pymatgen_version='2023...      36
# ...          ...                                                ...     ...
# 5299  mp-1229104  emmet_version='0.72.20' pymatgen_version='2023...      56
# 5301  mp-1229117  emmet_version='0.72.20' pymatgen_version='2023...      64
# 5310  mp-1247815  emmet_version='0.72.20' pymatgen_version='2023...      64
# 5314  mp-1247898  emmet_version='0.72.20' pymatgen_version='2023...      98
# 5317  mp-1267554  emmet_version='0.72.20' pymatgen_version='2023...      98
#
# ...

# %%
new_df['skorch_model_3_ESW'] = new_df['skorch_model_3_OXID_POT_Average_prediction'] - new_df['skorch_model_3_RED_POT_Average_prediction']
new_df
# Out:
#      material_id                                       builder_meta  nsites  \
# 0         mp-841  emmet_version='0.72.20' pymatgen_version='2023...       8
# 1        mp-2412  emmet_version='0.72.20' pymatgen_version='2023...      24
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 6        mp-4855  emmet_version='0.72.20' pymatgen_version='2023...      42
# 7        mp-6075  emmet_version='0.72.20' pymatgen_version='2023...      36
# ...          ...                                                ...     ...
# 5299  mp-1229104  emmet_version='0.72.20' pymatgen_version='2023...      56
# 5301  mp-1229117  emmet_version='0.72.20' pymatgen_version='2023...      64
# 5310  mp-1247815  emmet_version='0.72.20' pymatgen_version='2023...      64
# 5314  mp-1247898  emmet_version='0.72.20' pymatgen_version='2023...      98
# 5317  mp-1267554  emmet_version='0.72.20' pymatgen_version='2023...      98
#
# ...

# %%
new_df[['skorch_model_1_RED_POT_Average_prediction', 'skorch_model_2_RED_POT_Average_prediction', 'skorch_model_3_RED_POT_Average_prediction', 'skorch_model_1_OXID_POT_Average_prediction', 'skorch_model_2_OXID_POT_Average_prediction', 'skorch_model_3_OXID_POT_Average_prediction']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2610 entries, 0 to 5317
# Data columns (total 6 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   skorch_model_1_RED_POT_Average_prediction   2610 non-null   float64
#  1   skorch_model_2_RED_POT_Average_prediction   2610 non-null   float64
#  2   skorch_model_3_RED_POT_Average_prediction   2610 non-null   float64
#  3   skorch_model_1_OXID_POT_Average_prediction  2610 non-null   float64
#  4   skorch_model_2_OXID_POT_Average_prediction  2610 non-null   float64
#  5   skorch_model_3_OXID_POT_Average_prediction  2610 non-null   float64
# dtypes: float64(6)
# memory usage: 142.7 KB

# %%
new_df = new_df[new_df['skorch_model_1_ESW'] >= 4.0]
new_df = new_df[new_df['skorch_model_2_ESW'] >= 4.0]
new_df = new_df[new_df['skorch_model_3_ESW'] >= 4.0]

# %%
new_df
# Out:
#      material_id                                       builder_meta  nsites  \
# 2        mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 8        mp-6134  emmet_version='0.72.20' pymatgen_version='2023...      18
# 9        mp-6253  emmet_version='0.72.20' pymatgen_version='2023...      14
# 11       mp-6591  emmet_version='0.72.20' pymatgen_version='2023...      18
# 17       mp-8204  emmet_version='0.72.20' pymatgen_version='2023...      32
# ...          ...                                                ...     ...
# 5025   mp-540653  emmet_version='0.72.20' pymatgen_version='2023...      56
# 5035   mp-555507  emmet_version='0.72.20' pymatgen_version='2023...      76
# 5183  mp-1113633  emmet_version='0.72.20' pymatgen_version='2023...      10
# 5226  mp-1200608  emmet_version='0.72.20' pymatgen_version='2023...     224
# 5240  mp-1208679  emmet_version='0.72.20' pymatgen_version='2023...      54
#
# ...

# %%
new_df_Li = new_df[new_df['Li'] != 0]
new_df_Li
# Out:
#     material_id                                       builder_meta  nsites  \
# 2       mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 8       mp-6134  emmet_version='0.72.20' pymatgen_version='2023...      18
# 9       mp-6253  emmet_version='0.72.20' pymatgen_version='2023...      14
# 11      mp-6591  emmet_version='0.72.20' pymatgen_version='2023...      18
# 17      mp-8204  emmet_version='0.72.20' pymatgen_version='2023...      32
# 24      mp-9143  emmet_version='0.72.20' pymatgen_version='2023...       8
# 29      mp-9839  emmet_version='0.72.20' pymatgen_version='2023...      10
# 32     mp-10250  emmet_version='0.72.20' pymatgen_version='2023...       5
# 40     mp-15549  emmet_version='0.72.20' pymatgen_version='2023...      20
# 47     mp-22905  emmet_version='0.72.20' pymatgen_version='2023...       2
# 48     mp-23259  emmet_version='0.72.20' pymatgen_version='2023...       2
# ...

# %%
new_df_Li[new_df_Li['F'] != 0]
# Out:
#     material_id                                       builder_meta  nsites  \
# 8       mp-6134  emmet_version='0.72.20' pymatgen_version='2023...      18
# 9       mp-6253  emmet_version='0.72.20' pymatgen_version='2023...      14
# 11      mp-6591  emmet_version='0.72.20' pymatgen_version='2023...      18
# 24      mp-9143  emmet_version='0.72.20' pymatgen_version='2023...       8
# 29      mp-9839  emmet_version='0.72.20' pymatgen_version='2023...      10
# 32     mp-10250  emmet_version='0.72.20' pymatgen_version='2023...       5
# 40     mp-15549  emmet_version='0.72.20' pymatgen_version='2023...      20
# 67     mp-24199  emmet_version='0.72.20' pymatgen_version='2023...       4
# 166   mp-555591  emmet_version='0.72.20' pymatgen_version='2023...      36
# 174   mp-556996  emmet_version='0.72.20' pymatgen_version='2023...      30
# 284   mp-706611  emmet_version='0.72.20' pymatgen_version='2023...      44
# ...

# %%
new_df_Li[new_df_Li['Cl'] != 0]
# Out:
#     material_id                                       builder_meta  nsites  \
# 47     mp-22905  emmet_version='0.72.20' pymatgen_version='2023...       2
# 562  mp-1185319  emmet_version='0.72.20' pymatgen_version='2023...       4
#
#                      elements  nelements composition_reduced formula_pretty  \
# 47   [Element Cl, Element Li]          2             Li1 Cl1           LiCl
# 562  [Element Cl, Element Li]          2             Li1 Cl1           LiCl
#
#     formula_anonymous chemsys     volume  ...  exists  \
# 47                 AB   Cl-Li  32.856352  ...   False
# 562                AB   Cl-Li  84.810010  ...   False
#
#      skorch_model_1_RED_POT_Average_prediction  \
# 47                                    0.225812
# 562                                   0.225812
#
#     skorch_model_2_RED_POT_Average_prediction  \
# 47                                    0.22305
# 562                                   0.22305
#
#     skorch_model_3_RED_POT_Average_prediction  \
# ...

# %%
new_df_Li[new_df_Li['Br'] != 0]
# Out:
#     material_id                                       builder_meta  nsites  \
# 48     mp-23259  emmet_version='0.72.20' pymatgen_version='2023...       2
# 395   mp-976280  emmet_version='0.72.20' pymatgen_version='2023...       4
#
#                      elements  nelements composition_reduced formula_pretty  \
# 48   [Element Br, Element Li]          2             Li1 Br1           LiBr
# 395  [Element Br, Element Li]          2             Li1 Br1           LiBr
#
#     formula_anonymous chemsys     volume  ...  exists  \
# 48                 AB   Br-Li  40.366850  ...   False
# 395                AB   Br-Li  99.344502  ...   False
#
#      skorch_model_1_RED_POT_Average_prediction  \
# 48                                    0.335411
# 395                                   0.335411
#
#     skorch_model_2_RED_POT_Average_prediction  \
# 48                                   0.315829
# 395                                  0.315829
#
#     skorch_model_3_RED_POT_Average_prediction  \
# ...

# %%
new_df_Li[new_df_Li['I'] != 0]
# Out:
# Empty DataFrame
# ...

# %%
new_df_Li[new_df_Li['At'] != 0]
# Out:
# Empty DataFrame
# ...

# %%
new_df_Li_halide_4V = pd.concat([new_df_Li[new_df_Li['F'] != 0], new_df_Li[new_df_Li['Cl'] != 0], new_df_Li[new_df_Li['Br'] != 0], new_df_Li[new_df_Li['I'] != 0], new_df_Li[new_df_Li['At'] != 0]], axis = 0)
new_df_Li_halide_4V
# Out:
#     material_id                                       builder_meta  nsites  \
# 8       mp-6134  emmet_version='0.72.20' pymatgen_version='2023...      18
# 9       mp-6253  emmet_version='0.72.20' pymatgen_version='2023...      14
# 11      mp-6591  emmet_version='0.72.20' pymatgen_version='2023...      18
# 24      mp-9143  emmet_version='0.72.20' pymatgen_version='2023...       8
# 29      mp-9839  emmet_version='0.72.20' pymatgen_version='2023...      10
# 32     mp-10250  emmet_version='0.72.20' pymatgen_version='2023...       5
# 40     mp-15549  emmet_version='0.72.20' pymatgen_version='2023...      20
# 67     mp-24199  emmet_version='0.72.20' pymatgen_version='2023...       4
# 166   mp-555591  emmet_version='0.72.20' pymatgen_version='2023...      36
# 174   mp-556996  emmet_version='0.72.20' pymatgen_version='2023...      30
# 284   mp-706611  emmet_version='0.72.20' pymatgen_version='2023...      44
# ...

# %%
new_df_Li_halide_4V.to_csv('NEW_Shortlist_Li_halides_4V_from_SCREENED_MPJ_18_July_2025.csv', index = False)

# %%
new_df_Li_halide_4V[['material_id', 'formula_pretty', 'formation_energy_per_atom', 'energy_above_hull', 'band_gap', 'theoretical',
                                'skorch_model_1_RED_POT_Average_prediction', 'skorch_model_2_RED_POT_Average_prediction', 'skorch_model_3_RED_POT_Average_prediction',
                                'skorch_model_1_OXID_POT_Average_prediction', 'skorch_model_2_OXID_POT_Average_prediction', 'skorch_model_3_OXID_POT_Average_prediction',
                               'skorch_model_1_ESW', 'skorch_model_2_ESW', 'skorch_model_3_ESW']].describe()
# Out:
#        formation_energy_per_atom  energy_above_hull   band_gap  \
# count                  26.000000          26.000000  26.000000
# mean                   -3.028533           0.006492   6.678473
# std                     0.713933           0.010651   1.272678
# min                    -3.877836           0.000000   2.476700
# 25%                    -3.470127           0.000000   6.157825
# 50%                    -3.215822           0.000058   7.200100
# 75%                    -2.523814           0.008332   7.515000
# max                    -1.807240           0.034970   8.596500
#
#        skorch_model_1_RED_POT_Average_prediction  \
# count                                  26.000000
# mean                                    1.135198
# std                                     0.749793
# min                                     0.225812
# 25%                                     0.663205
# 50%                                     0.852915
# ...

# %%
new_df_Li_halide_4V[['material_id', 'formula_pretty', 'formation_energy_per_atom', 'energy_above_hull', 'band_gap', 'theoretical',
                                'skorch_model_1_RED_POT_Average_prediction', 'skorch_model_2_RED_POT_Average_prediction', 'skorch_model_3_RED_POT_Average_prediction',
                                'skorch_model_1_OXID_POT_Average_prediction', 'skorch_model_2_OXID_POT_Average_prediction', 'skorch_model_3_OXID_POT_Average_prediction',
                               'skorch_model_1_ESW', 'skorch_model_2_ESW', 'skorch_model_3_ESW']].to_csv('1-NEW_Shortlist_Li_halides_4V_from_SCREENED_MPJ_18_July_2025.csv', index = False)

# %%
new_df_Li_halide_4V['theoretical'].value_counts()
# Out:
# theoretical
# False    16
# True     10
# Name: count, dtype: int64

# %%
new_df_Li[new_df_Li['F'] != 0][['material_id', 'formula_pretty', 'theoretical',
                                'skorch_model_1_RED_POT_Average_prediction', 'skorch_model_2_RED_POT_Average_prediction', 'skorch_model_3_RED_POT_Average_prediction',
                                'skorch_model_1_OXID_POT_Average_prediction', 'skorch_model_2_OXID_POT_Average_prediction', 'skorch_model_3_OXID_POT_Average_prediction',
                               'skorch_model_1_ESW', 'skorch_model_2_ESW', 'skorch_model_3_ESW']]
# Out:
#     material_id formula_pretty  theoretical  \
# 8       mp-6134       LiCaAlF6        False
# 9       mp-6253        KLiBeF4        False
# 11      mp-6591       SrLiAlF6        False
# 24      mp-9143          LiPF6        False
# 29      mp-9839       K2LiAlF6        False
# 32     mp-10250         BaLiF3        False
# 40     mp-15549       K2LiAlF6        False
# 67     mp-24199          LiHF2        False
# 166   mp-555591       SrLiAlF6        False
# 174   mp-556996       K2LiAlF6        False
# 284   mp-706611      LiBeH4NF4        False
# 402   mp-989504       Na2LiNF6         True
# 489  mp-1111112       K2LiGaF6         True
# 492  mp-1111671       K2LiInF6         True
# 497  mp-1113747      Rb2LiAlF6         True
# 499  mp-1114242      Na2LiGaF6         True
# 559  mp-1180580          LiHF2         True
# 566  mp-1188485         Li2BF5        False
# 586  mp-1193222       LiMgAlF6        False
# 602  mp-1195827       SrLiAlF6        False
# ...

# %%
new_df_Li[new_df_Li['Cl'] != 0][['material_id', 'formula_pretty', 'theoretical',
                                'skorch_model_1_RED_POT_Average_prediction', 'skorch_model_2_RED_POT_Average_prediction', 'skorch_model_3_RED_POT_Average_prediction',
                                'skorch_model_1_OXID_POT_Average_prediction', 'skorch_model_2_OXID_POT_Average_prediction', 'skorch_model_3_OXID_POT_Average_prediction',
                               'skorch_model_1_ESW', 'skorch_model_2_ESW', 'skorch_model_3_ESW']]
# Out:
#     material_id formula_pretty  theoretical  \
# 47     mp-22905           LiCl        False
# 562  mp-1185319           LiCl         True
#
#      skorch_model_1_RED_POT_Average_prediction  \
# 47                                    0.225812
# 562                                   0.225812
#
#      skorch_model_2_RED_POT_Average_prediction  \
# 47                                     0.22305
# 562                                    0.22305
#
#      skorch_model_3_RED_POT_Average_prediction  \
# 47                                    0.223224
# 562                                   0.223224
#
#      skorch_model_1_OXID_POT_Average_prediction  \
# 47                                     5.486818
# 562                                    5.486818
#
#      skorch_model_2_OXID_POT_Average_prediction  \
# 47                                     5.546803
# 562                                    5.546803
#
#      skorch_model_3_OXID_POT_Average_prediction  skorch_model_1_ESW  \
# ...

# %%
new_df_Li[new_df_Li['Br'] != 0][['material_id', 'formula_pretty', 'theoretical',
                                'skorch_model_1_RED_POT_Average_prediction', 'skorch_model_2_RED_POT_Average_prediction', 'skorch_model_3_RED_POT_Average_prediction',
                                'skorch_model_1_OXID_POT_Average_prediction', 'skorch_model_2_OXID_POT_Average_prediction', 'skorch_model_3_OXID_POT_Average_prediction',
                               'skorch_model_1_ESW', 'skorch_model_2_ESW', 'skorch_model_3_ESW']]
# Out:
#     material_id formula_pretty  theoretical  \
# 48     mp-23259           LiBr        False
# 395   mp-976280           LiBr         True
#
#      skorch_model_1_RED_POT_Average_prediction  \
# 48                                    0.335411
# 395                                   0.335411
#
#      skorch_model_2_RED_POT_Average_prediction  \
# 48                                    0.315829
# 395                                   0.315829
#
#      skorch_model_3_RED_POT_Average_prediction  \
# 48                                    0.303593
# 395                                   0.303593
#
#      skorch_model_1_OXID_POT_Average_prediction  \
# 48                                     5.361798
# 395                                    5.361798
#
#      skorch_model_2_OXID_POT_Average_prediction  \
# 48                                     5.418663
# 395                                    5.418663
#
#      skorch_model_3_OXID_POT_Average_prediction  skorch_model_1_ESW  \
# ...

# %%
new_df_Li[new_df_Li['I'] != 0][['material_id', 'formula_pretty', 'theoretical',
                                'skorch_model_1_RED_POT_Average_prediction', 'skorch_model_2_RED_POT_Average_prediction', 'skorch_model_3_RED_POT_Average_prediction',
                                'skorch_model_1_OXID_POT_Average_prediction', 'skorch_model_2_OXID_POT_Average_prediction', 'skorch_model_3_OXID_POT_Average_prediction',
                               'skorch_model_1_ESW', 'skorch_model_2_ESW', 'skorch_model_3_ESW']]
# Out:
# Empty DataFrame
# Columns: [material_id, formula_pretty, theoretical, skorch_model_1_RED_POT_Average_prediction, skorch_model_2_RED_POT_Average_prediction, skorch_model_3_RED_POT_Average_prediction, skorch_model_1_OXID_POT_Average_prediction, skorch_model_2_OXID_POT_Average_prediction, skorch_model_3_OXID_POT_Average_prediction, skorch_model_1_ESW, skorch_model_2_ESW, skorch_model_3_ESW]
# Index: []

# %%
new_df_Li[['material_id', 'formula_pretty', 'formation_energy_per_atom', 'energy_above_hull', 'band_gap', 'theoretical',
                                'skorch_model_1_RED_POT_Average_prediction', 'skorch_model_2_RED_POT_Average_prediction', 'skorch_model_3_RED_POT_Average_prediction',
                                'skorch_model_1_OXID_POT_Average_prediction', 'skorch_model_2_OXID_POT_Average_prediction', 'skorch_model_3_OXID_POT_Average_prediction',
                               'skorch_model_1_ESW', 'skorch_model_2_ESW', 'skorch_model_3_ESW']]
# Out:
#     material_id formula_pretty  formation_energy_per_atom  energy_above_hull  \
# 2       mp-2659           LiN3                  -0.205822           0.000000
# 8       mp-6134       LiCaAlF6                  -3.871874           0.000000
# 9       mp-6253        KLiBeF4                  -3.354594           0.000000
# 11      mp-6591       SrLiAlF6                  -3.877836           0.000000
# 17      mp-8204        LiAlB14                  -0.191040           0.000000
# 24      mp-9143          LiPF6                  -2.924595           0.000000
# 29      mp-9839       K2LiAlF6                  -3.464196           0.001649
# 32     mp-10250         BaLiF3                  -3.742865           0.021903
# 40     mp-15549       K2LiAlF6                  -3.465729           0.000116
# 47     mp-22905           LiCl                  -2.025595           0.000000
# 48     mp-23259           LiBr                  -1.807240           0.009896
# ...

# %%
new_df_Li[['material_id', 'formula_pretty', 'formation_energy_per_atom', 'energy_above_hull', 'band_gap', 'theoretical',
                                'skorch_model_1_RED_POT_Average_prediction', 'skorch_model_2_RED_POT_Average_prediction', 'skorch_model_3_RED_POT_Average_prediction',
                                'skorch_model_1_OXID_POT_Average_prediction', 'skorch_model_2_OXID_POT_Average_prediction', 'skorch_model_3_OXID_POT_Average_prediction',
                               'skorch_model_1_ESW', 'skorch_model_2_ESW', 'skorch_model_3_ESW']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28 entries, 2 to 651
# Data columns (total 15 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   material_id                                 28 non-null     object
#  1   formula_pretty                              28 non-null     object
#  2   formation_energy_per_atom                   28 non-null     float64
#  3   energy_above_hull                           28 non-null     float64
#  4   band_gap                                    28 non-null     float64
#  5   theoretical                                 28 non-null     bool
#  6   skorch_model_1_RED_POT_Average_prediction   28 non-null     float64
#  7   skorch_model_2_RED_POT_Average_prediction   28 non-null     float64
#  8   skorch_model_3_RED_POT_Average_prediction   28 non-null     float64
#  9   skorch_model_1_OXID_POT_Average_prediction  28 non-null     float64
# ...

# %%
new_df_Li_halide_4V[['material_id', 'formula_pretty', 'formation_energy_per_atom', 'energy_above_hull', 'band_gap', 'theoretical',
                                'skorch_model_1_RED_POT_Average_prediction', 'skorch_model_2_RED_POT_Average_prediction', 'skorch_model_3_RED_POT_Average_prediction',
                                'skorch_model_1_OXID_POT_Average_prediction', 'skorch_model_2_OXID_POT_Average_prediction', 'skorch_model_3_OXID_POT_Average_prediction',
                               'skorch_model_1_ESW', 'skorch_model_2_ESW', 'skorch_model_3_ESW']].describe().to_csv('NEW_Statistics_of_ESW_predictions_by_best_ML_models_for_SCREENED_Li_halides_4V_from_MPJ_dataset_18_July_2025.csv')

# %%
new_df_Li_halide_4V[['material_id', 'formula_pretty', 'formation_energy_per_atom', 'energy_above_hull', 'band_gap', 'theoretical',
                                'skorch_model_1_RED_POT_Average_prediction', 'skorch_model_2_RED_POT_Average_prediction', 'skorch_model_3_RED_POT_Average_prediction',
                                'skorch_model_1_OXID_POT_Average_prediction', 'skorch_model_2_OXID_POT_Average_prediction', 'skorch_model_3_OXID_POT_Average_prediction',
                               'skorch_model_1_ESW', 'skorch_model_2_ESW', 'skorch_model_3_ESW']].describe()
# Out:
#        formation_energy_per_atom  energy_above_hull   band_gap  \
# count                  26.000000          26.000000  26.000000
# mean                   -3.028533           0.006492   6.678473
# std                     0.713933           0.010651   1.272678
# min                    -3.877836           0.000000   2.476700
# 25%                    -3.470127           0.000000   6.157825
# 50%                    -3.215822           0.000058   7.200100
# 75%                    -2.523814           0.008332   7.515000
# max                    -1.807240           0.034970   8.596500
#
#        skorch_model_1_RED_POT_Average_prediction  \
# count                                  26.000000
# mean                                    1.135198
# std                                     0.749793
# min                                     0.225812
# 25%                                     0.663205
# 50%                                     0.852915
# ...

# %%
new_df_Li
# Out:
#     material_id                                       builder_meta  nsites  \
# 2       mp-2659  emmet_version='0.72.20' pymatgen_version='2023...       4
# 8       mp-6134  emmet_version='0.72.20' pymatgen_version='2023...      18
# 9       mp-6253  emmet_version='0.72.20' pymatgen_version='2023...      14
# 11      mp-6591  emmet_version='0.72.20' pymatgen_version='2023...      18
# 17      mp-8204  emmet_version='0.72.20' pymatgen_version='2023...      32
# 24      mp-9143  emmet_version='0.72.20' pymatgen_version='2023...       8
# 29      mp-9839  emmet_version='0.72.20' pymatgen_version='2023...      10
# 32     mp-10250  emmet_version='0.72.20' pymatgen_version='2023...       5
# 40     mp-15549  emmet_version='0.72.20' pymatgen_version='2023...      20
# 47     mp-22905  emmet_version='0.72.20' pymatgen_version='2023...       2
# 48     mp-23259  emmet_version='0.72.20' pymatgen_version='2023...       2
# ...

# %%
new_df_Li.to_csv('NEW_Shortlist_Li_compounds_4V_from_SCREENED_MPJ_18_July_2025.csv', index = False)

# %%
new_df_Li[['material_id', 'formula_pretty', 'formation_energy_per_atom', 'energy_above_hull', 'band_gap', 'theoretical',
                                'skorch_model_1_RED_POT_Average_prediction', 'skorch_model_2_RED_POT_Average_prediction', 'skorch_model_3_RED_POT_Average_prediction',
                                'skorch_model_1_OXID_POT_Average_prediction', 'skorch_model_2_OXID_POT_Average_prediction', 'skorch_model_3_OXID_POT_Average_prediction',
                               'skorch_model_1_ESW', 'skorch_model_2_ESW', 'skorch_model_3_ESW']].to_csv('1-NEW_Shortlist_Li_compounds_4V_from_SCREENED_MPJ_18_July_2025.csv', index = False)
